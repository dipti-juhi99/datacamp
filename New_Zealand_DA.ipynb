# %% [markdown]
# # NEW ZEALAND EDA

# %% [markdown]
# The main purpose of Exploratory Data Analysis is to help look at the data before making any assumption, The Covid-19 pandemic is the most crucial health disaster that has surrounded the world for the past year. The following data helps us to understand the consequences of the COVID‐19 outbreak.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats
import matplotlib.pyplot as plt

# %% [markdown]
# read_csv is an important pandas function to read the csv files and do operations on it. and df.head() returns the 1st 5 rows. "owid_covid_data" is the data am working with.

# %%
df = pd.read_csv("New-covid-data(NZ).csv")
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %% [markdown]
# # New Zealand EDA

# %% [markdown]
# ## here is the details of country New Zealand

# %%
x = df.groupby(df.location)
new_zealand = x.get_group("New Zealand")
new_zealand
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 50789      NZL   Oceania  New Zealand  2020-02-28          1.0        1.0
# 50790      NZL   Oceania  New Zealand  2020-02-29          1.0        0.0
# 50791      NZL   Oceania  New Zealand  2020-03-01          1.0        0.0
# 50792      NZL   Oceania  New Zealand  2020-03-02          1.0        0.0
# 50793      NZL   Oceania  New Zealand  2020-03-03          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 51187      NZL   Oceania  New Zealand  2021-04-01       2501.0        0.0
# 51188      NZL   Oceania  New Zealand  2021-04-02       2501.0        0.0
# 51189      NZL   Oceania  New Zealand  2021-04-03       2501.0        0.0
# 51190      NZL   Oceania  New Zealand  2021-04-04       2507.0        6.0
# 51191      NZL   Oceania  New Zealand  2021-04-05       2524.0       17.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %% [markdown]
# We change the index number starting from 50789 - 51191 to 0-403 for easy understaning and readability.

# %%
new_zealand=new_zealand.reset_index()
new_zealand.drop('index', axis=1, inplace=True)
new_zealand
# Out:
#     iso_code continent     location        date  total_cases  new_cases  \
# 0        NZL   Oceania  New Zealand  2020-02-28          1.0        1.0
# 1        NZL   Oceania  New Zealand  2020-02-29          1.0        0.0
# 2        NZL   Oceania  New Zealand  2020-03-01          1.0        0.0
# 3        NZL   Oceania  New Zealand  2020-03-02          1.0        0.0
# 4        NZL   Oceania  New Zealand  2020-03-03          1.0        0.0
# ..       ...       ...          ...         ...          ...        ...
# 398      NZL   Oceania  New Zealand  2021-04-01       2501.0        0.0
# 399      NZL   Oceania  New Zealand  2021-04-02       2501.0        0.0
# 400      NZL   Oceania  New Zealand  2021-04-03       2501.0        0.0
# 401      NZL   Oceania  New Zealand  2021-04-04       2507.0        6.0
# 402      NZL   Oceania  New Zealand  2021-04-05       2524.0       17.0
#
#      new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %% [markdown]
# We now find the null values present in the given series of object. Using the 'isnull().sum()' function, one can find the number of missing values per coumn.

# %%
new_zealand.isnull().sum()
# Out:
# iso_code                                   0
# continent                                  0
# location                                   0
# date                                       0
# total_cases                                0
# new_cases                                  0
# new_cases_smoothed                         5
# total_deaths                              30
# new_deaths                                30
# new_deaths_smoothed                        5
# total_cases_per_million                    0
# new_cases_per_million                      0
# new_cases_smoothed_per_million             5
# total_deaths_per_million                  30
# new_deaths_per_million                    30
# new_deaths_smoothed_per_million            5
# reproduction_rate                         26
# icu_patients                             403
# icu_patients_per_million                 403
# hosp_patients                            403
# hosp_patients_per_million                403
# ...

# %%
new_zealand.shape
# Out:
# (403, 59)

# %% [markdown]
# the new_zealand.shape tells that there are 222 rows and 41 columns in the DataFrame for the country new_zealand

# %%
new_zealand.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
# ...

# %% [markdown]
# We can also determine the null values in-terms of percentage

# %%
features_with_na=[features for features in new_zealand.columns if new_zealand[features].isnull().sum()>1]
for feature in features_with_na:
    print(feature, np.round(new_zealand[feature].isnull().mean(), 4),  ' % missing values')
# Out:
# new_cases_smoothed 0.0124  % missing values
# total_deaths 0.0744  % missing values
# new_deaths 0.0744  % missing values
# new_deaths_smoothed 0.0124  % missing values
# new_cases_smoothed_per_million 0.0124  % missing values
# total_deaths_per_million 0.0744  % missing values
# new_deaths_per_million 0.0744  % missing values
# new_deaths_smoothed_per_million 0.0124  % missing values
# reproduction_rate 0.0645  % missing values
# icu_patients 1.0  % missing values
# icu_patients_per_million 1.0  % missing values
# hosp_patients 1.0  % missing values
# hosp_patients_per_million 1.0  % missing values
# weekly_icu_admissions 1.0  % missing values
# weekly_icu_admissions_per_million 1.0  % missing values
# weekly_hosp_admissions 1.0  % missing values
# weekly_hosp_admissions_per_million 1.0  % missing values
# new_tests 0.1985  % missing values
# total_tests 0.1216  % missing values
# total_tests_per_thousand 0.1216  % missing values
# new_tests_per_thousand 0.1985  % missing values
# ...

# %%
new_zealand.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 403 entries, 0 to 402
# Data columns (total 59 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               403 non-null    object
#  1   continent                              403 non-null    object
#  2   location                               403 non-null    object
#  3   date                                   403 non-null    object
#  4   total_cases                            403 non-null    float64
#  5   new_cases                              403 non-null    float64
#  6   new_cases_smoothed                     398 non-null    float64
#  7   total_deaths                           373 non-null    float64
#  8   new_deaths                             373 non-null    float64
#  9   new_deaths_smoothed                    398 non-null    float64
# ...

# %% [markdown]
# Using the heatmap, we can clearly locate the null values present in each column

# %%
plt.figure(figsize=(25,5))
sns.heatmap(new_zealand.isnull(),yticklabels=False)
plt.title("Heatmap showing the null values present in dataframe-new_zealand_EDA")
# Out:
# Text(0.5, 1.0, 'Heatmap showing the null values present in dataframe-new_zealand_EDA')

# %% [markdown]
# From the above heatmap, we can see that there are many values near to 0 which means that there is no dependence between the occurence of missing values, As we can the null values present in few columns, and also few coulmns are entirely having null value, so we can drop those column using drop() function

# %%
new_zealand.drop(columns=['icu_patients', 'icu_patients_per_million','weekly_icu_admissions','weekly_icu_admissions_per_million',
                       'weekly_icu_admissions_per_million','weekly_hosp_admissions_per_million','hosp_patients','hosp_patients_per_million',
                       'handwashing_facilities'], axis =1 ,inplace =True)
new_zealand.drop(columns=['weekly_hosp_admissions'], axis =1 ,inplace =True)

# %%
plt.figure(figsize=(25,5))
sns.heatmap(new_zealand.isnull(),yticklabels=False)
plt.title("Heatmap showing the null values present in dataframe-new_zealand_EDA")
# Out:
# Text(0.5, 1.0, 'Heatmap showing the null values present in dataframe-new_zealand_EDA')

# %%
new_zealand['people_fully_vaccinated']=new_zealand['people_fully_vaccinated'].fillna(new_zealand['people_fully_vaccinated'].mean())
new_zealand['people_fully_vaccinated_per_hundred']=new_zealand['people_fully_vaccinated_per_hundred'].fillna(new_zealand['people_fully_vaccinated_per_hundred'].mean())

# %% [markdown]
# 1. Distrubution plot for total vaccinations provided

# %%
sns.set(rc={'figure.figsize':(6,3)})
sns.distplot(new_zealand.total_vaccinations)
new_zealand['total_vaccinations'].describe()
# Out:
# C:\Users\dipti juhi\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# count       10.000000
# mean     16722.700000
# std      23060.276726
# min          0.000000
# 25%        325.000000
# 50%       5465.500000
# 75%      24750.000000
# max      68666.000000
# Name: total_vaccinations, dtype: float64

# %% [markdown]
# 2. Distrubution plot showing the number of people vaccinated

# %%
sns.set(rc={'figure.figsize':(6,3)})
sns.distplot(new_zealand.people_vaccinated)
new_zealand['people_vaccinated'].describe()
# Out:
# C:\Users\dipti juhi\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# count       10.000000
# mean     15074.400000
# std      19201.113383
# min          0.000000
# 25%        325.000000
# 50%       5465.500000
# 75%      24750.000000
# max      52183.000000
# Name: people_vaccinated, dtype: float64

# %% [markdown]
# 3. Distrubution plot for total vaccinations provided

# %%
sns.set(rc={'figure.figsize':(6,3)})
sns.distplot(new_zealand.total_vaccinations)
new_zealand['total_vaccinations'].describe()
# Out:
# C:\Users\dipti juhi\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# count       10.000000
# mean     16722.700000
# std      23060.276726
# min          0.000000
# 25%        325.000000
# 50%       5465.500000
# 75%      24750.000000
# max      68666.000000
# Name: total_vaccinations, dtype: float64

# %% [markdown]
# 4. Distrubution plot shows that people who are fully vaccinated

# %%
sns.set(rc={'figure.figsize':(6,3)})
sns.distplot(new_zealand.people_fully_vaccinated)
new_zealand['people_fully_vaccinated'].describe()
# Out:
# C:\Users\dipti juhi\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\dipti juhi\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# count      403.0
# mean     16483.0
# std          0.0
# min      16483.0
# 25%      16483.0
# 50%      16483.0
# 75%      16483.0
# max      16483.0
# Name: people_fully_vaccinated, dtype: float64

# %% [markdown]
# 5. Distrubution plot for the new_vaccinations available

# %%
sns.set(rc={'figure.figsize':(6,3)})
sns.distplot(new_zealand.new_vaccinations)
new_zealand['new_vaccinations'].describe()
# Out:
# C:\Users\dipti juhi\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# count     2.000000
# mean     50.000000
# std      28.284271
# min      30.000000
# 25%      40.000000
# 50%      50.000000
# 75%      60.000000
# max      70.000000
# Name: new_vaccinations, dtype: float64

# %%
sns.set(rc={'figure.figsize':(6,3)})
sns.distplot(new_zealand.new_vaccinations_smoothed)
new_zealand['new_vaccinations_smoothed'].describe()
# Out:
# C:\Users\dipti juhi\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# count      41.000000
# mean     1396.878049
# std      1013.107156
# min        30.000000
# 25%       513.000000
# 50%      1286.000000
# 75%      1833.000000
# max      3881.000000
# Name: new_vaccinations_smoothed, dtype: float64

# %% [markdown]
# 6. Distrubution plot for total_vaccinations_per_hundred

# %%
sns.set(rc={'figure.figsize':(6,3)})
sns.distplot(new_zealand.total_vaccinations_per_hundred)
new_zealand['total_vaccinations_per_hundred'].describe()
# Out:
# C:\Users\dipti juhi\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# count    10.000000
# mean      0.346000
# std       0.477335
# min       0.000000
# 25%       0.005000
# 50%       0.115000
# 75%       0.512500
# max       1.420000
# Name: total_vaccinations_per_hundred, dtype: float64

# %%
sns.set(rc={'figure.figsize':(6,3)})
sns.distplot(new_zealand.people_vaccinated_per_hundred)
new_zealand['people_vaccinated_per_hundred'].describe()
# Out:
# C:\Users\dipti juhi\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# count    10.000000
# mean      0.312000
# std       0.397822
# min       0.000000
# 25%       0.005000
# 50%       0.115000
# 75%       0.512500
# max       1.080000
# Name: people_vaccinated_per_hundred, dtype: float64

# %% [markdown]
# 8. Distrubution plot for people_fully_vaccinated_per_hundred

# %%
sns.set(rc={'figure.figsize':(6,3)})
sns.distplot(new_zealand.people_fully_vaccinated_per_hundred)
new_zealand['people_fully_vaccinated_per_hundred'].describe()
# Out:
# C:\Users\dipti juhi\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\dipti juhi\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# count    4.030000e+02
# mean     3.400000e-01
# std      2.556687e-15
# min      3.400000e-01
# 25%      3.400000e-01
# 50%      3.400000e-01
# 75%      3.400000e-01
# max      3.400000e-01
# Name: people_fully_vaccinated_per_hundred, dtype: float64

# %% [markdown]
# 9. Distrubution plot for new_vaccinations_smoothed_per_million

# %%
sns.set(rc={'figure.figsize':(6,3)})
sns.distplot(new_zealand.new_vaccinations_smoothed_per_million)
new_zealand['new_vaccinations_smoothed_per_million'].describe()
# Out:
# C:\Users\dipti juhi\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# count     41.000000
# mean     289.658537
# std      210.117421
# min        6.000000
# 25%      106.000000
# 50%      267.000000
# 75%      380.000000
# max      805.000000
# Name: new_vaccinations_smoothed_per_million, dtype: float64

# %%
new_zealand.describe().loc[:,['total_vaccinations','people_vaccinated','people_fully_vaccinated','new_vaccinations',
                           'new_vaccinations_smoothed','total_vaccinations_per_hundred','people_vaccinated_per_hundred',
                           'people_fully_vaccinated_per_hundred','new_vaccinations_smoothed_per_million']]
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count           10.000000          10.000000                    403.0
# mean         16722.700000       15074.400000                  16483.0
# std          23060.276726       19201.113383                      0.0
# min              0.000000           0.000000                  16483.0
# 25%            325.000000         325.000000                  16483.0
# 50%           5465.500000        5465.500000                  16483.0
# 75%          24750.000000       24750.000000                  16483.0
# max          68666.000000       52183.000000                  16483.0
#
#        new_vaccinations  new_vaccinations_smoothed  \
# count          2.000000                  41.000000
# mean          50.000000                1396.878049
# std           28.284271                1013.107156
# min           30.000000                  30.000000
# 25%           40.000000                 513.000000
# ...

# %% [markdown]
# The following heatmap shows that its the correlation heatmap representing the country new_zealand. The correlation matrix contains the number of vaccinations which were available and how many people are vaccinated partially and how many people are fully vaccinated

# %%
new_zealand_corr = new_zealand[['total_vaccinations','people_vaccinated','people_fully_vaccinated','new_vaccinations',
                           'new_vaccinations_smoothed','total_vaccinations_per_hundred','people_vaccinated_per_hundred',
                           'people_fully_vaccinated_per_hundred','new_vaccinations_smoothed_per_million']].corr()
plt.figure(figsize=(8,6))
sns.heatmap(new_zealand_corr,annot = True,vmin =1,vmax=1,cmap ='GnBu_r')
plt.title("Correlation Matrix of Slovakia_EDA")
new_zealand_corr
# Out:
#                                        total_vaccinations  people_vaccinated  \
# total_vaccinations                           1.000000e+00       9.861379e-01
# people_vaccinated                            9.861379e-01       1.000000e+00
# people_fully_vaccinated                               NaN                NaN
# new_vaccinations                             1.000000e+00       1.000000e+00
# new_vaccinations_smoothed                    9.793184e-01       9.527889e-01
# total_vaccinations_per_hundred               9.999903e-01       9.863657e-01
# people_vaccinated_per_hundred                9.859592e-01       9.999871e-01
# people_fully_vaccinated_per_hundred          6.651727e-17       3.994317e-17
# new_vaccinations_smoothed_per_million        9.792050e-01       9.526243e-01
#
#                                        people_fully_vaccinated  \
# total_vaccinations                                         NaN
# people_vaccinated                                          NaN
# ...

# %% [markdown]
# These coulmns are filled with the mean values so as to remove the null value from the respective columns

# %%
new_zealand['total_vaccinations']=new_zealand['total_vaccinations'].fillna(new_zealand['total_vaccinations'].mean())
new_zealand['people_vaccinated']=new_zealand['people_vaccinated'].fillna(new_zealand['people_vaccinated'].mean())

new_zealand['people_fully_vaccinated']=new_zealand['people_fully_vaccinated'].fillna(new_zealand['people_fully_vaccinated'].mean())
new_zealand['new_vaccinationsnew_vaccinations']=new_zealand['new_vaccinations'].fillna(new_zealand['new_vaccinations'].mean())

new_zealand['new_vaccinations_smoothed']=new_zealand['new_vaccinations_smoothed'].fillna(new_zealand['new_vaccinations_smoothed'].mean())
new_zealand['total_vaccinations_per_hundred']=new_zealand['total_vaccinations_per_hundred'].fillna(new_zealand['total_vaccinations_per_hundred'].mean())

new_zealand['people_vaccinated_per_hundred']=new_zealand['people_vaccinated_per_hundred'].fillna(new_zealand['people_vaccinated_per_hundred'].mean())
new_zealand['people_fully_vaccinated_per_hundred']=new_zealand['people_fully_vaccinated_per_hundred'].fillna(new_zealand['people_fully_vaccinated_per_hundred'].mean())

new_zealand['new_vaccinations']=new_zealand['new_vaccinations'].fillna(new_zealand['new_vaccinations'].mean())
new_zealand['new_vaccinations_smoothed_per_million']=new_zealand['new_vaccinations_smoothed_per_million'].fillna(new_zealand['new_vaccinations_smoothed_per_million'].mean())

# %%
plt.figure(figsize=(25,5))
sns.heatmap(new_zealand.isnull(),yticklabels=False)
plt.title("Heatmap showing the null values present in dataframe-new_zealand_EDA")
# Out:
# Text(0.5, 1.0, 'Heatmap showing the null values present in dataframe-new_zealand_EDA')

# %% [markdown]
# we use describe function to view the stastical details like percentile,mean etc of a dataframe.

# %%
new_zealand.describe().loc[:,['new_cases_smoothed','total_deaths','new_deaths','new_deaths_smoothed','new_cases_smoothed_per_million',
                           'new_deaths_per_million','total_deaths_per_million','new_deaths_smoothed_per_million','reproduction_rate',
                          'new_tests_smoothed','new_tests_smoothed_per_thousand',
                           'positive_rate','tests_per_case']]
# Out:
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# count          398.000000    373.000000  373.000000           398.000000
# mean             6.291116     22.536193    0.069705             0.065349
# std             13.217634      5.178731    0.359912             0.207174
# min              0.000000      1.000000    0.000000             0.000000
# 25%              1.571000     22.000000    0.000000             0.000000
# 50%              3.000000     25.000000    0.000000             0.000000
# 75%              4.535500     25.000000    0.000000             0.000000
# max             75.000000     26.000000    4.000000             1.286000
#
#        new_cases_smoothed_per_million  new_deaths_per_million  \
# count                      398.000000              373.000000
# mean                         1.304545                0.014442
# std                          2.740977                0.074596
# ...

# %% [markdown]
# The following correlation matrix contains the number of deaths that took place and the positive rate and the number of test per case

# %%
new_zealand_corr = new_zealand[['new_cases_smoothed','total_deaths','new_deaths','new_deaths_smoothed','new_cases_smoothed_per_million',
                           'new_deaths_per_million','total_deaths_per_million','new_deaths_smoothed_per_million','reproduction_rate',
                          'new_tests_smoothed','new_tests_smoothed_per_thousand',
                           'positive_rate','tests_per_case']].corr()
plt.figure(figsize=(15,10))
sns.heatmap(new_zealand_corr,annot = True,vmin =1,vmax=1,cmap ='GnBu_r')
plt.title("Correlation Matrix of new_zealand_EDA")
new_zealand_corr
# Out:
#                                  new_cases_smoothed  total_deaths  new_deaths  \
# new_cases_smoothed                         1.000000     -0.878334    0.197783
# total_deaths                              -0.878334      1.000000   -0.321534
# new_deaths                                 0.197783     -0.321534    1.000000
# new_deaths_smoothed                        0.188120     -0.443878    0.576914
# new_cases_smoothed_per_million             1.000000     -0.878337    0.197787
# new_deaths_per_million                     0.197760     -0.321459    1.000000
# total_deaths_per_million                  -0.878337      1.000000   -0.321524
# new_deaths_smoothed_per_million            0.188774     -0.444460    0.577079
# reproduction_rate                          0.316535      0.024608   -0.175251
# new_tests_smoothed                        -0.103138      0.221870   -0.057450
# new_tests_smoothed_per_thousand           -0.103084      0.221836   -0.057460
# ...

# %% [markdown]
# These coulmns are filled with the mean values so as to remove the null value from the respective columns

# %%
new_zealand['new_cases_smoothed']=new_zealand['new_cases_smoothed'].fillna(new_zealand['new_cases_smoothed'].mean())
new_zealand['total_deaths']=new_zealand['total_deaths'].fillna(new_zealand['total_deaths'].mean())

new_zealand['new_deaths']=new_zealand['new_deaths'].fillna(new_zealand['new_deaths'].mean())
new_zealand['new_deaths_smoothed']=new_zealand['new_deaths_smoothed'].fillna(new_zealand['new_deaths_smoothed'].mean())

new_zealand['new_cases_smoothed_per_million']=new_zealand['new_cases_smoothed_per_million'].fillna(new_zealand['new_cases_smoothed_per_million'].mean())
new_zealand['new_deaths_per_million']=new_zealand['new_deaths_per_million'].fillna(new_zealand['new_deaths_per_million'].mean())

new_zealand['total_deaths_per_million']=new_zealand['total_deaths_per_million'].fillna(new_zealand['total_deaths_per_million'].mean())
new_zealand['new_deaths_smoothed_per_million']=new_zealand['new_deaths_smoothed_per_million'].fillna(new_zealand['new_deaths_smoothed_per_million'].mean())

new_zealand['reproduction_rate']=new_zealand['reproduction_rate'].fillna(new_zealand['reproduction_rate'].mean())
new_zealand['new_tests_smoothed']=new_zealand['new_tests_smoothed'].fillna(new_zealand['new_tests_smoothed'].mean())

new_zealand['new_tests_smoothed_per_thousand']=new_zealand['new_tests_smoothed_per_thousand'].fillna(new_zealand['new_tests_smoothed_per_thousand'].mean())
new_zealand['positive_rate']=new_zealand['positive_rate'].fillna(new_zealand['positive_rate'].median())
new_zealand['tests_per_case']=new_zealand['tests_per_case'].fillna(new_zealand['tests_per_case'].mean())

new_zealand['stringency_index']=new_zealand['stringency_index'].fillna(new_zealand['stringency_index'].mean())
new_zealand['new_tests']=new_zealand['new_tests'].fillna(new_zealand['new_tests'].mean())

# %%
plt.figure(figsize=(25,5))
sns.heatmap(new_zealand.isnull(),yticklabels=False)
plt.title("Heatmap showing the null values present in dataframe-new_zealand_EDA")
# Out:
# Text(0.5, 1.0, 'Heatmap showing the null values present in dataframe-new_zealand_EDA')

# %% [markdown]
# The function info() tells us that the number of null values and number of non-null values present in the dataframe

# %%
new_zealand.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 403 entries, 0 to 402
# Data columns (total 51 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               403 non-null    object
#  1   continent                              403 non-null    object
#  2   location                               403 non-null    object
#  3   date                                   403 non-null    object
#  4   total_cases                            403 non-null    float64
#  5   new_cases                              403 non-null    float64
#  6   new_cases_smoothed                     403 non-null    float64
#  7   total_deaths                           403 non-null    float64
#  8   new_deaths                             403 non-null    float64
#  9   new_deaths_smoothed                    403 non-null    float64
# ...

# %% [markdown]
# As we can observe in the above table, that the date in the given dataframe is of the type object. So converting it into data_time object

# %%
new_zealand['date'] = pd.to_datetime(new_zealand['date'],format='%Y-%m-%d')

# %%
print("Starting date =",new_zealand['date'].min())
print("End date =",new_zealand['date'].max())
print("Length of data with respect to days :",new_zealand['date'].max()-new_zealand['date'].min())
# Out:
# Starting date = 2020-02-28 00:00:00
# End date = 2021-04-05 00:00:00
# Length of data with respect to days : 402 days 00:00:00

# %% [markdown]
# ### we have the New zealand _country data for 373 days that is from 6th march 2020 (2020-03-06) to 14th March 2020 (2020-03-14)
# ### Now we can obsverve the given data interms of line_plot which shows the clear representation of that particular feature with respect to that particular date
# ### 1. plot showing the number of total cases with respect to date

# %%
plt.figure(figsize=(10,6))
plt.plot(new_zealand['date'],new_zealand['total_cases'])
plt.title('total_cases')
plt.tick_params(axis='x', rotation=0)

# %% [markdown]
# ### 2. plot showing the number of new cases with respect to date

# %%
plt.figure(figsize=(10,6))
plt.plot(new_zealand['date'],new_zealand['new_cases'])
plt.title('new_cases')
plt.tick_params(axis='x', rotation=0)

# %% [markdown]
# ### 3. plot showing the number of new_cases_smoothed with respect to date

# %%
plt.figure(figsize=(10,6))
plt.plot(new_zealand['date'],new_zealand['new_cases_smoothed'])
plt.title('new_cases_smoothed')
plt.tick_params(axis='x', rotation=0)

# %% [markdown]
# ### 4. plot showing the number of total_deaths with respect to date

# %%
plt.figure(figsize=(10,6))
plt.plot(new_zealand['date'],new_zealand['total_deaths'])
plt.title('total_deaths')
plt.tick_params(axis='x', rotation=0)

# %% [markdown]
# ### 5. plot showing the number of new_deaths with respect to date

# %%
plt.figure(figsize=(10,6))
plt.plot(new_zealand['date'],new_zealand['new_deaths'])
plt.title('new_deaths')
plt.tick_params(axis='x', rotation=0)

# %% [markdown]
# ### 6. plot showing the number of new_deaths_smoothed with respect to date

# %%
plt.figure(figsize=(10,6))
plt.plot(new_zealand['date'],new_zealand['new_deaths_smoothed'])
plt.title('new_deaths_smoothed')
plt.tick_params(axis='x', rotation=0)

# %% [markdown]
# ### 7. plot showing the number of total_deaths_per_million with respect to date

# %%
plt.figure(figsize=(10,6))
plt.plot(new_zealand['date'],new_zealand['total_deaths_per_million'])
plt.title('total_deaths_per_million')
plt.tick_params(axis='x', rotation=0)

# %% [markdown]
# ### 8. plot showing the number of new_deaths_per_million with respect to date

# %%
plt.figure(figsize=(10,6))
plt.plot(new_zealand['date'],new_zealand['new_deaths_per_million'])
plt.title('new_deaths_per_million')
plt.tick_params(axis='x', rotation=0)

# %% [markdown]
# ### 9. plot showing the number of new_deaths_smoothed_per_million with respect to date

# %%
plt.figure(figsize=(10,6))
plt.plot(new_zealand['date'],new_zealand['new_deaths_smoothed_per_million'])
plt.title('new_deaths_smoothed_per_million')
plt.tick_params(axis='x', rotation=0)

# %% [markdown]
# ### 10. plot showing the number of new_tests with respect to date

# %%
plt.figure(figsize=(10,6))
plt.plot(new_zealand['date'],new_zealand['new_tests'])
plt.title('new_tests')
plt.tick_params(axis='x', rotation=0)

# %% [markdown]
# ### 11. plot showing the number of total_tests with respect to date

# %%
plt.figure(figsize=(10,6))
plt.plot(new_zealand['date'],new_zealand['total_tests'])
plt.title('total_tests')
plt.tick_params(axis='x', rotation=0)

# %% [markdown]
# ### 12. plot showing the number of positive_rate with respect to date

# %%
plt.figure(figsize=(10,6))
plt.plot(new_zealand['date'],new_zealand['positive_rate'])
plt.title('positive_rate')
plt.tick_params(axis='x', rotation=0)

# %% [markdown]
# ### 13. plot showing the number of stringency_index with respect to date

# %%
plt.figure(figsize=(10,6))
plt.plot(new_zealand['date'],new_zealand['stringency_index'])
plt.title('stringency_index')
plt.tick_params(axis='x', rotation=0)

# %% [markdown]
# ### Adding a new feature 'month' to findout the requirements with respect to each month

# %%
new_zealand['month'] = new_zealand['date'].dt.month_name()

# %%
new_zealand.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'new_tests',
#        'total_tests', 'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
#        'new_vaccinations_smoothed', 'total_vaccinations_per_hundred',
#        'people_vaccinated_per_hundred', 'people_fully_vaccinated_per_hundred',
#        'new_vaccinations_smoothed_per_million', 'stringency_index',
# ...

# %% [markdown]
# # Scatter plots

# %%
for i, feature in enumerate(new_zealand.columns[2:len(new_zealand.columns)-2]):
    
    plt.figure(i)
    plt.figure(figsize=(10,5))
    g = sns.scatterplot(x=new_zealand.total_cases,y=feature,data=new_zealand).set_title(feature +" vs total cases  for new zealand ")
# Out:
# <ipython-input-50-15e9830234fe>:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(10,5))

# %%
new_zealand_new = new_zealand.loc[:,'date':'stringency_index']

# %% [markdown]
# ### Now, we group the gven data in months, so that we can find out the features with respect to each month

# %%
new_zealanda = new_zealand.groupby(new_zealand.month).sum()
new_zealanda = new_zealanda.reindex(['April','May','June','July','August','September','October','November','December',
             'January', 'February','March'])
new_zealanda = new_zealanda.loc[:,['total_cases','new_cases','new_cases_smoothed','total_deaths','new_deaths','new_deaths_smoothed','total_cases_per_million',
                             'new_cases_per_million','new_cases_smoothed_per_million','total_deaths_per_million','new_deaths_per_million',
                             'new_deaths_smoothed_per_million','total_tests','positive_rate','tests_per_case','total_vaccinations',
                             'people_vaccinated','stringency_index']]

# %%
##The following table tells the variation of each feature with repect to the month
new_zealanda
# Out:
#            total_cases  new_cases  new_cases_smoothed  total_deaths  \
# month
# April          51393.0      855.0         1049.716000    402.000000
# May            46429.0       25.0           32.428000    652.000000
# June           45317.0       24.0           20.430000    660.000000
# July           47976.0       34.0           34.145000    682.000000
# August         50692.0      190.0          163.858000    682.000000
# September      54113.0       96.0          112.571000    730.000000
# October        58768.0      111.0          113.430000    775.000000
# November       60239.0      100.0          100.286000    750.000000
# December       65370.0      103.0          100.140000    775.000000
# January        69608.0      142.0          151.142000    775.000000
# February       65509.0       75.0           83.012231    759.072386
# March          79249.0      769.0          574.161347   1440.013405
#
#            new_deaths  new_deaths_smoothed  total_cases_per_million  \
# ...

# %% [markdown]
# ### so the above table shows that all features in the given data are grouped according to respective months. We can see that the total cases for each month is increasing rapidly, and even the number of new cases and number of deaths that are taking place each month is increasing

# %%
new_zealanda.index
# Out:
# Index(['April', 'May', 'June', 'July', 'August', 'September', 'October',
#        'November', 'December', 'January', 'February', 'March'],
#       dtype='object', name='month')

# %% [markdown]
# The following plots gives us the clear picture of each feature of the dataframe with respect to that particular month for country Slovakia (2020-2021)

# %% [markdown]
# ### 1. line_plot showing the number of total cases for each month

# %%
plt.figure(figsize=(12,6))
g = sns.lineplot(x=new_zealanda.index,y=new_zealanda.total_cases,data=new_zealanda)
g.set_xticklabels(new_zealanda.index,rotation=45)
g.set_title("total_cases vs month  for new zealand ")
# Out:
# <ipython-input-55-fc6842e91464>:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   g.set_xticklabels(new_zealanda.index,rotation=45)
# Text(0.5, 1.0, 'total_cases vs month  for new zealand ')

# %% [markdown]
# ### 2. line_plot showing the number of new cases for each month

# %%
plt.figure(figsize=(12,6))
g = sns.lineplot(x=new_zealanda.index,y=new_zealanda.new_cases,data=new_zealanda)
g.set_xticklabels(new_zealanda.index,rotation=45)
g.set_title("new_cases vs month for new zealand ")
# Out:
# <ipython-input-56-5fe80ed049de>:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   g.set_xticklabels(new_zealanda.index,rotation=45)
# Text(0.5, 1.0, 'new_cases vs month for new zealand ')

# %% [markdown]
# ### 3. line_plot showing the number of new_cases_smoothed for each month

# %%
plt.figure(figsize=(12,6))
g = sns.lineplot(x=new_zealanda.index,y=new_zealanda.new_cases_smoothed,data=new_zealanda)
g.set_xticklabels(new_zealanda.index,rotation=45)
g.set_title("new_cases_smoothed vs month  for new zealand ")
# Out:
# <ipython-input-57-eee129679935>:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   g.set_xticklabels(new_zealanda.index,rotation=45)
# Text(0.5, 1.0, 'new_cases_smoothed vs month  for new zealand ')

# %% [markdown]
# ### 4. line_plot showing the number of total_deaths for each month

# %%
plt.figure(figsize=(12,6))
g = sns.lineplot(x=new_zealanda.index,y=new_zealanda.total_deaths,data=new_zealanda)
g.set_xticklabels(new_zealanda.index,rotation=45)
g.set_title("total_deaths vs month  for new zealand ")
# Out:
# <ipython-input-58-d734d62ccb92>:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   g.set_xticklabels(new_zealanda.index,rotation=45)
# Text(0.5, 1.0, 'total_deaths vs month  for new zealand ')

# %% [markdown]
# ### 5. line_plot showing the number of new_deaths for each month

# %%
plt.figure(figsize=(12,6))
g = sns.lineplot(x=new_zealanda.index,y=new_zealanda.new_deaths,data=new_zealanda)
g.set_xticklabels(new_zealanda.index,rotation=45)
g.set_title("new_deaths vs month  for new zealand ")
# Out:
# <ipython-input-59-5e7a3a0581f0>:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   g.set_xticklabels(new_zealanda.index,rotation=45)
# Text(0.5, 1.0, 'new_deaths vs month  for new zealand ')

# %% [markdown]
# ### 6. line_plot showing the number of new_deaths_smoothed for each month

# %%
plt.figure(figsize=(12,6))
g = sns.lineplot(x=new_zealanda.index,y=new_zealanda.new_deaths_smoothed,data=new_zealanda)
g.set_xticklabels(new_zealanda.index,rotation=45)
g.set_title("new_deaths_smoothed vs month  for new zealand ")
# Out:
# <ipython-input-60-b582c061588b>:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   g.set_xticklabels(new_zealanda.index,rotation=45)
# Text(0.5, 1.0, 'new_deaths_smoothed vs month  for new zealand ')

# %% [markdown]
# ### 7. line_plot showing the number of total_cases_per_million for each month

# %%
plt.figure(figsize=(12,6))
g = sns.lineplot(x=new_zealanda.index,y=new_zealanda.total_cases_per_million,data=new_zealanda)
g.set_xticklabels(new_zealanda.index,rotation=45)
g.set_title("total_cases_per_million vs month  for new zealand ")
# Out:
# <ipython-input-61-72d03eac2e56>:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   g.set_xticklabels(new_zealanda.index,rotation=45)
# Text(0.5, 1.0, 'total_cases_per_million vs month  for new zealand ')

# %% [markdown]
# ### 8. line_plot showing the number of new_cases_per_million for each month

# %%
plt.figure(figsize=(12,6))
g = sns.lineplot(x=new_zealanda.index,y=new_zealanda.new_cases_per_million,data=new_zealanda)
g.set_xticklabels(new_zealanda.index,rotation=45)
g.set_title("new_cases_per_million vs month  for new zealand ")
# Out:
# <ipython-input-62-dcaf5ef405f9>:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   g.set_xticklabels(new_zealanda.index,rotation=45)
# Text(0.5, 1.0, 'new_cases_per_million vs month  for new zealand ')

# %% [markdown]
# ### 9. line_plot showing the number of total_deaths_per_million for each month

# %%
plt.figure(figsize=(12,6))
g = sns.lineplot(x=new_zealanda.index,y=new_zealanda.total_deaths_per_million,data=new_zealanda)
g.set_xticklabels(new_zealanda.index,rotation=45)
g.set_title("total_deaths_per_million vs month  for new zealand ")
# Out:
# <ipython-input-63-30a91861cb16>:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   g.set_xticklabels(new_zealanda.index,rotation=45)
# Text(0.5, 1.0, 'total_deaths_per_million vs month  for new zealand ')

# %% [markdown]
# ### 10. line_plot showing the number of total_tests for each month

# %%
plt.figure(figsize=(12,6))
g = sns.lineplot(x=new_zealanda.index,y=new_zealanda.total_tests,data=new_zealanda)
g.set_xticklabels(new_zealanda.index,rotation=45)
g.set_title("total_tests vs month  for new zealand ")
# Out:
# <ipython-input-64-40cceefcc1d9>:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   g.set_xticklabels(new_zealanda.index,rotation=45)
# Text(0.5, 1.0, 'total_tests vs month  for new zealand ')

# %% [markdown]
# ### 11. line_plot showing the number of positive_rate for each month

# %%
plt.figure(figsize=(12,6))
g = sns.lineplot(x=new_zealanda.index,y=new_zealanda.positive_rate,data=new_zealanda)
g.set_xticklabels(new_zealanda.index,rotation=45)
g.set_title("positive_rate vs month  for new zealand ")
# Out:
# <ipython-input-65-2981dea09af5>:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   g.set_xticklabels(new_zealanda.index,rotation=45)
# Text(0.5, 1.0, 'positive_rate vs month  for new zealand ')

# %% [markdown]
# ### 12. line_plot showing the number of stringency_index for each month

# %%
plt.figure(figsize=(12,6))
g = sns.lineplot(x=new_zealanda.index,y=new_zealanda.stringency_index,data=new_zealanda)
g.set_xticklabels(new_zealanda.index,rotation=45)
g.set_title("stringency_index vs month  for new zealand ")
# Out:
# <ipython-input-66-2a53f80feba8>:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   g.set_xticklabels(new_zealanda.index,rotation=45)
# Text(0.5, 1.0, 'stringency_index vs month  for new zealand ')

# %% [markdown]
# The above lineplots shows the variation of cases for each month. We can also plot the same using bar_plot for better understanding for country Slovakia (2020-2021)

# %% [markdown]
# # 1. bar_plot showing the number of total_cases for each month

# %%
plt.figure(figsize=(12,6))
g = sns.barplot(x=new_zealanda.index,y=new_zealanda.total_cases,data=new_zealanda)
g.set_xticklabels(new_zealanda.index,rotation=45)
g.set_title("total_cases vs month  for new zealand ")
# Out:
# Text(0.5, 1.0, 'total_cases vs month  for new zealand ')

# %% [markdown]
# # 2. bar_plot showing the number of new_cases for each month

# %%
plt.figure(figsize=(12,6))
g = sns.barplot(x=new_zealanda.index,y=new_zealanda.new_cases,data=new_zealanda)
g.set_xticklabels(new_zealanda.index,rotation=45)
g.set_title("new_cases vs month  for new zealand ")
# Out:
# Text(0.5, 1.0, 'new_cases vs month  for new zealand ')

# %% [markdown]
# # 3. bar_plot showing the number of total_deaths for each month

# %%
plt.figure(figsize=(12,6))
g = sns.barplot(x=new_zealanda.index,y=new_zealanda.total_deaths,data=new_zealanda)
g.set_xticklabels(new_zealanda.index,rotation=45)
g.set_title("total_deaths vs month  for new zealand ")
# Out:
# Text(0.5, 1.0, 'total_deaths vs month  for new zealand ')

# %% [markdown]
# # 4. bar_plot showing the number of new_deaths for each month

# %%
plt.figure(figsize=(12,6))
g = sns.barplot(x=new_zealanda.index,y=new_zealanda.new_deaths,data=new_zealanda)
g.set_xticklabels(new_zealanda.index,rotation=45)
g.set_title("new_deaths vs month  for new zealand ")
# Out:
# Text(0.5, 1.0, 'new_deaths vs month  for new zealand ')

# %% [markdown]
# # 5. bar_plot showing the number of total_cases_per_million for each month

# %%
plt.figure(figsize=(12,6))
g = sns.barplot(x=new_zealanda.index,y=new_zealanda.total_cases_per_million,data=new_zealanda)
g.set_xticklabels(new_zealanda.index,rotation=45)
g.set_title("total_cases_per_million vs month  for new zealand ")
# Out:
# Text(0.5, 1.0, 'total_cases_per_million vs month  for new zealand ')

# %% [markdown]
# # 6. bar_plot showing the number of new_cases_per_million for each month

# %%
plt.figure(figsize=(12,6))
g = sns.barplot(x=new_zealanda.index,y=new_zealanda.new_cases_per_million,data=new_zealanda)
g.set_xticklabels(new_zealanda.index,rotation=45)
g.set_title("new_cases_per_million vs month  for new zealand ")
# Out:
# Text(0.5, 1.0, 'new_cases_per_million vs month  for new zealand ')

# %% [markdown]
# # 7. bar_plot showing the number of total_deaths_per_million for each month

# %%
plt.figure(figsize=(12,6))
g = sns.barplot(x=new_zealanda.index,y=new_zealanda.total_deaths_per_million,data=new_zealanda)
g.set_xticklabels(new_zealanda.index,rotation=45)
g.set_title("total_deaths_per_million vs month  for new zealand ")
# Out:
# Text(0.5, 1.0, 'total_deaths_per_million vs month  for new zealand ')

# %% [markdown]
#  # 8. bar_plot showing the number of total_tests for each month

# %%
plt.figure(figsize=(12,6))
g = sns.barplot(x=new_zealanda.index,y=new_zealanda.total_tests,data=new_zealanda)
g.set_xticklabels(new_zealanda.index,rotation=45)
g.set_title("total_tests vs month  for new zealand ")
# Out:
# Text(0.5, 1.0, 'total_tests vs month  for new zealand ')

# %% [markdown]
# # 9. bar_plot showing the number of positive_rate for each month

# %%
plt.figure(figsize=(12,6))
g = sns.barplot(x=new_zealanda.index,y=new_zealanda.positive_rate,data=new_zealanda)
g.set_xticklabels(new_zealanda.index,rotation=45)
g.set_title("positive_rate vs month  for new zealand ")
# Out:
# Text(0.5, 1.0, 'positive_rate vs month  for new zealand ')

# %% [markdown]
# # 10. bar_plot showing the number of stringency_index for each month

# %%
plt.figure(figsize=(12,6))
g = sns.barplot(x=new_zealanda.index,y=new_zealanda.stringency_index,data=new_zealanda)
g.set_xticklabels(new_zealanda.index,rotation=45)
g.set_title("stringency_index vs month for new zealand")
# Out:
# Text(0.5, 1.0, 'stringency_index vs month for new zealand')

# %% [markdown]
# # SIR model

# %% [markdown]
# ## For the epidemical mathematical model, basic models that are based on compartments, as shown in the following, were used:
# # 1.(Susceptible->Infectible) SI model,
# # 2.(Susceptible->Infectible-> Susceptible) SIS model,
# # 3.(Susceptible->Infectible-> Recovery/Removed) SIR model.

# %% [markdown]
# # So we will only be studying about the SIR model

# %% [markdown]
# In 1927, Kermack and McKendrick first proposed a class of compartmental models that simplified the mathematical modeling of infectious disease transmission. The SIR model is a set of general equations that explain the dynamics of an infectious disease spreading through a susceptible population.The SIR model is a basic model of an infectious disease outbreak in a large population.The population is believed to be made up of three groups of people, whose numbers are denoted by the letters S, I, and R. (which is why this is called an SIR model). All of these are time functions that change according to a system of differential equations

# %% [markdown]
# # Susceptible S(t) is used to represent the individuals not yet infected with the disease at time t, or those susceptible to the disease of the population.

# %% [markdown]
# ## Infected I(t) denotes the individuals of the population who have been infected with the disease and are capable of spreading the disease to those in the susceptible category. infected represents the new_cases in our dataset

# %% [markdown]
# ## Recovered R(t) is the compartment used for the individuals of the population who have been infected and then removed from the disease, either due to immunization or due to death. Those in this category are not able to be infected again or to transmit the infection to others

# %% [markdown]
# ## Implementing the following differential equations
# # 1. Susceptible : dS/dt = −(β/N)SI or S′(t) = − [β ⋅ I(t) ⋅ S(t) / N]
# # 2. Infected : dI/dt = (β/N)SI−γI or I′(t) = + [β ⋅ I(t) ⋅ S(t) / N] − [γ ⋅ I(t)]
# # 3. Removed : dR/dt = γI or R′(t) = + [γ ⋅ I(t)]
# ## Here, N=S+I+R or N(t) = S(t)+I(t)+R(t) is independent of time t and denotes the total population size¶

# %% [markdown]
# ## Defining the SIR parameters as follows

# %% [markdown]
# ### ● β (beta) : Expected amount of people an infected person infects per day. β is the transmission rate constant.
# ### ● D : Number of days an infected person has and can spread the disease
# ### ● γ (gamma) : The proportion of infected removed per day (γ = 1/D). γ the removal rate constant.
# ### ● R0 : The total number of people an infected person infects (R0 = β/γ)
# ### ● β (beta) and γ (gamma) are real, positive, parameters of the initial exponential growth and final exponential decay of the infected population I.¶

# %% [markdown]
# # Importing the required libraries!

# %%
from scipy.integrate import solve_ivp
from scipy.optimize import minimize
import matplotlib.pyplot as plt
from datetime import timedelta, datetime
from scipy.integrate import odeint

# %%
new_zealand.head()
# Out:
#   iso_code continent     location       date  total_cases  new_cases  \
# 0      NZL   Oceania  New Zealand 2020-02-28          1.0        1.0
# 1      NZL   Oceania  New Zealand 2020-02-29          1.0        0.0
# 2      NZL   Oceania  New Zealand 2020-03-01          1.0        0.0
# 3      NZL   Oceania  New Zealand 2020-03-02          1.0        0.0
# 4      NZL   Oceania  New Zealand 2020-03-03          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0            6.291116     22.536193    0.069705             0.065349  ...
# 1            6.291116     22.536193    0.069705             0.065349  ...
# 2            6.291116     22.536193    0.069705             0.065349  ...
# 3            6.291116     22.536193    0.069705             0.065349  ...
# 4            6.291116     22.536193    0.069705             0.065349  ...
#
#    extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# ...

# %%
new_zealand.tail()
# Out:
#     iso_code continent     location       date  total_cases  new_cases  \
# 398      NZL   Oceania  New Zealand 2021-04-01       2501.0        0.0
# 399      NZL   Oceania  New Zealand 2021-04-02       2501.0        0.0
# 400      NZL   Oceania  New Zealand 2021-04-03       2501.0        0.0
# 401      NZL   Oceania  New Zealand 2021-04-04       2507.0        6.0
# 402      NZL   Oceania  New Zealand 2021-04-05       2524.0       17.0
#
#      new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 398               3.143          26.0         0.0                  0.0  ...
# 399               2.857          26.0         0.0                  0.0  ...
# 400               2.714          26.0         0.0                  0.0  ...
# 401               2.000          26.0         0.0                  0.0  ...
# 402               4.143          26.0         0.0                  0.0  ...
#
#      extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# ...

# %% [markdown]
# #### As we can see from the dataframe, the covid has started on 06/03/2020 in country Slovakia

# %% [markdown]
# ### The total population in the country Slovakia is found below.

# %%
N = new_zealand.population[0]
N
# Out:
# 4822233.0

# %% [markdown]
# ### Hence the total population is 4822233. hence N = 4822233
#
# ### Now, we will be finding the mean value of the reproduction rate

# %%
mean_r0=new_zealand['reproduction_rate'].mean()
mean_r0
# Out:
# 0.8845358090185687

# %%
for i in new_zealand['total_cases']:
    if i>0:
        break
i
# Out:
# 1.0

# %% [markdown]
# #### Initial conditions are as follows- 1. Reproduction number R0= 1.1308 2. Infectious period t_infectious= 3.3 days 3. Incubation period t_incubation= 5.1 days 4. Population N = 4822233 5. Initial number of infected people i0= 1 the values are found as, the reproduction rate from the mean value. the Incubation period t_incubation and Infectious period is obtained from, https://www.sciencedaily.com/releases/2020/03/200310164744.htm https://doi.org/10.3390/jcm9020571 the values of N which means the total population in New Zealand

# %%
plt.figure(figsize=(15,6))
plt.plot(new_zealand['date'],new_zealand['reproduction_rate'])
plt.title('reproduction_rate')
plt.tick_params(axis='x', rotation=0)

# %% [markdown]
# #### As we can see from the above lineplot, the reproduction rate was increasing initially in the month of march-april and it decreased completely in month of may and it gradually increased till month of july
#
# ### As per the given condition, we willl be dividing our model into 4 different periods,
# #### 1. first period - starting date ⇒ peak with the initial parameters. 2. second period - starting date ⇒ end of first wave with the initial parameters. 3. third period - peak date ⇒ end of first wave with the peak parameters. 4. fourth period - starting of second-wave ⇒ the last date with the parameters of the starting of the second wave.
# ### As the conditions mentioned above, we will now find the number of days per each period
# #### 1. First wave - starting date is 06-03-2020, the peak value was 114 cases on 18-04-2020. 2. First wave - starting date is 06-03-2020, the end of the 1st wave was on 25-06-2020. 3. Second wave - starting date is 26-06-2020, the peak value was 6315 cases on 01-01-2021 4. Second wave - starting date is 26-06-2020, till end.
# ### So, we can find the number of days from above data.
# #### 1. From the starting date 06-03-2020 till the peak value of 1st wave 18-04-2020, the number of days is 43 days. 3. The total days for the start and end of the 1st wave is [06-03-2020 to 25-06-2020] 111 days. 2. From the peak value 18-04-2020 of 1st wave till the end of the 1st wave 25-06-2020, there are 68 days. 4. The total days from the starting date of 2nd wave 26-06-2020 till 14-03-2021 is 262 days.
# ### Now we need to find the mean value of reproduction [r0] rate for each period

# %%
r0_period1= new_zealand['reproduction_rate'][0:44].mean()
r0_period2= new_zealand['reproduction_rate'][0:112].mean()
r0_period3= new_zealand['reproduction_rate'][43:112].mean()
r0_period4= new_zealand['reproduction_rate'][262:].mean()

print(r0_period1, r0_period2, r0_period3, r0_period4)
# Out:
# 1.1238377140101292 0.6929362447896933 0.41927536231884044 0.9679366781421067

# %% [markdown]
# ##### Defining the differential equation for the SIR model

# %%
def deriv(x, t, beta, gamma):
    s, i, r = x
    dsdt = -(beta * s * i)/N
    didt = +(beta * s * i)/N - [gamma * i]          
    drdt = +gamma * i
    return [dsdt, didt, drdt]

# %% [markdown]
# ##### Implementing the model for Period 1 and for Period 2

# %%
# For period 1

R0_p1 = r0_period1

#t_infectious= 5,t_incubation= 3.3
t_infective = 14

# initial number of infected and recovered individuals
i_initial1 = i
r_initial1 = 0.00
s_initial1 = N - i_initial1 - r_initial1 

gamma = 1/t_infective
beta1 = R0_p1

# For period 2
R0_p2 = r0_period2

#t_infectious= 5,t_incubation= 3.3
t_infective = 14

# initial number of infected and recovered individuals
i_initial2 = i
r_initial2 = 0.00
s_initial2 = N - i_initial2 - r_initial2

gamma = 1/t_infective
beta2 = R0_p2

# %%
t1 = np.linspace(0, 43, 43)  # Grid of time points (in days)
x_initial1 = s_initial1, i_initial1, r_initial1
soln1 = odeint(deriv, x_initial1, t1, args=(beta1, gamma))
s1, i1, r1 = soln1.T
e = None

t2 = np.linspace(0, 112, 112)  # Grid of time points (in days)
x_initial2 = s_initial2, i_initial2, r_initial2
soln2 = odeint(deriv, x_initial2, t2, args=(beta2, gamma))
s2, i2, r2 = soln2.T
e = None

# %%
fig= plt.figure()
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

ax1.plot(t1, s1, lw=3, label='Total Number of Susceptible')
ax1.plot(t1, i1, lw=3, label='Total Number of Infective')
ax1.plot(t1, r1, lw=3, label='Recovered')
ax1.set_title('Susceptible and Recovered Populations- Period 1')
ax1.set_xlabel('Time /days')
ax1.set_ylabel('Total Number of SIR individuals')
ax1.legend(loc='center right')

ax2.plot(t2, s2, lw=3, label='Total Number of Susceptible')
ax2.plot(t2, i2, lw=3, label='Total Number of Infective')
ax2.plot(t2, r2, lw=3, label='Recovered')
ax2.set_title('Susceptible and Recovered Populations- Period 2')
ax2.set_xlabel('Time /days')
ax2.set_ylabel('Total Number of SIR individuals')
ax2.legend(loc='center right')


fig.set_figheight(5)
fig.set_figwidth(16)

plt.show()

# %% [markdown]
# ### As we can find out the active cases using the formula as

# %% [markdown]
# ##### Active Cases = [Total_Cases] - [total_cases_shifted]

# %%
new_zealand['total_cases_shifted']= new_zealand.total_cases.shift(14)
new_zealand['active_cases_calc']=new_zealand['total_cases']-new_zealand['total_cases_shifted']
new_zealand['susceptible']= new_zealand['population']-new_zealand['total_cases']

# %% [markdown]
# ### Implementing the model for Period 3 and for Period 4

# %%
# For period 3
R0_p3 = r0_period3

#t_infectious= 5,t_incubation= 3.3
t_infective = 14

# initial number of infected and recovered individuals
i_initial3= new_zealand.loc[43, 'active_cases_calc']/N
r_initial3= (N-new_zealand.loc[43, 'total_cases'])/N
s_initial3= N-i_initial3-r_initial3

gamma = 1/t_infective
beta3 = R0_p3

# For period 4
R0_p4 = r0_period4

#t_infectious= 5,t_incubation= 3.3
t_infective = 14

# initial number of infected and recovered individuals
i_initial4= new_zealand.loc[224, 'active_cases_calc']/N
r_initial4= (N-new_zealand.loc[224, 'total_cases'])/N
s_initial4= N-i_initial4-r_initial4

gamma = 1/t_infective
beta4 = R0_p4

# %%
t3 = np.linspace(0, 69, 69)  # Grid of time points (in days)
x_initial3 = s_initial3, i_initial3, r_initial3
soln3 = odeint(deriv, x_initial3, t3, args=(beta3, gamma))
s3, i3, r3 = soln3.T
e = None

t4 = np.linspace(0, 189, 189)  # Grid of time points (in days)
x_initial4 = s_initial4, i_initial4, r_initial4
soln4 = odeint(deriv, x_initial4, t4, args=(beta4, gamma))
s4, i4, r4 = soln4.T
e = None

# %%
fig= plt.figure()
ax3 = fig.add_subplot(1,2,1)
ax4 = fig.add_subplot(1,2,2)

ax3.plot(t3, s3, lw=3, label='Total Number of Susceptible')
ax3.plot(t3, i3, lw=3, label='Total Number of Infective')
ax3.plot(t3, r3, lw=3, label='Recovered')
ax3.set_title('Susceptible and Recovered Populations- Period 3')
ax3.set_xlabel('Time /days')
ax3.set_ylabel('Total Number of SIR individuals')
ax3.legend()

ax4.plot(t4, s4, lw=3, label='Total Number of Susceptible')
ax4.plot(t4, i4, lw=3, label='Total Number of Infective')
ax4.plot(t4, r4, lw=3, label='Recovered')
ax4.set_title('Susceptible and Recovered Populations- Period 4')
ax4.set_xlabel('Time /days')
ax4.set_ylabel('Total Number of SIR individuals')
ax4.legend()

fig.set_figheight(5)
fig.set_figwidth(16)

plt.show()

# %% [markdown]
# ### Implementing all the models by taking beta value as the mean of reproduction rate

# %%
r0= new_zealand['reproduction_rate'].mean()

# For period 1
R0_p1 = r0

#t_infectious= 5,t_incubation= 3.3
t_infective = 14

# initial number of infected and recovered individuals
i_initial1 = i
r_initial1 = 0.00
s_initial1 = N - i_initial1 - r_initial1 

gamma = 1/t_infective
beta1 = R0_p1

# For period 2
R0_p2 = r0

#t_infectious= 5,t_incubation= 3.3
t_infective = 14

# initial number of infected and recovered individuals
i_initial2 = i
r_initial2 = 0.00
s_initial2 = N - i_initial2 - r_initial2

gamma = 1/t_infective
beta2 = R0_p2


# For period 3
R0 = r0

#t_infectious= 5,t_incubation= 3.3
t_infective = 14

# initial number of infected and recovered individuals
i_initial3= new_zealand.loc[43, 'active_cases_calc']/N
r_initial3= (N-new_zealand.loc[43, 'total_cases'])/N
s_initial3= N-i_initial3-r_initial3

gamma = 1/t_infective
beta3 = R0

# For period 4
R0_p4 = r0

#t_infectious= 5,t_incubation= 3.3
t_infective = 14

# initial number of infected and recovered individuals
i_initial4= new_zealand.loc[262, 'active_cases_calc']/N
r_initial4= (N-new_zealand.loc[262, 'total_cases'])/N
s_initial4= N-i_initial4-r_initial4

gamma = 1/t_infective
beta4 = R0_p4

# %%
t1 = np.linspace(0, 43, 43)  # Grid of time points (in days)
x_initial1 = s_initial1, i_initial1, r_initial1
soln1 = odeint(deriv, x_initial1, t1, args=(beta1, gamma))
s1, i1, r1 = soln1.T
e = None

t2 = np.linspace(0, 111, 112)  # Grid of time points (in days)
x_initial2 = s_initial2, i_initial2, r_initial2
soln2 = odeint(deriv, x_initial2, t2, args=(beta2, gamma))
s2, i2, r2 = soln2.T
e = None

t3 = np.linspace(0, 68, 68)  # Grid of time points (in days)
x_initial3 = s_initial3, i_initial3, r_initial3
soln3 = odeint(deriv, x_initial3, t3, args=(beta3, gamma))
s3, i3, r3 = soln3.T
e = None

t4 = np.linspace(0, 189, 189)  # Grid of time points (in days)
x_initial4 = s_initial4, i_initial4, r_initial4
soln4 = odeint(deriv, x_initial4, t4, args=(beta4, gamma))
s4, i4, r4 = soln4.T
e = None

# %%
fig= plt.figure()

ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)


ax1.plot(t1, s1, lw=3, label='Total Number of Susceptible')
ax1.plot(t1, i1, lw=3, label='Total Number of Infective')
ax1.plot(t1, r1, lw=3, label='Recovered')
ax1.set_title('Susceptible and Recovered Populations- Period 1')
ax1.set_xlabel('Time /days')
ax1.set_ylabel('Total Number of SIR individuals')
ax1.legend(loc='center right')

ax2.plot(t2, s2, lw=3, label='Total Number of Susceptible')
ax2.plot(t2, i2, lw=3, label='Total Number of Infective')
ax2.plot(t2, r2, lw=3, label='Recovered')
ax2.set_title('Susceptible and Recovered Populations- Period 2')
ax2.set_xlabel('Time /days')
ax2.set_ylabel('Total Number of SIR individuals')
ax2.legend(loc='center right')


ax3.plot(t3, s3, lw=3, label='Total Number of Susceptible')
ax3.plot(t3, i3, lw=3, label='Total Number of Infective')
ax3.plot(t3, r3, lw=3, label='Recovered')
ax3.set_title('Susceptible and Recovered Populations- Period 3')
ax3.set_xlabel('Time /days')
ax3.set_ylabel('Total Number of SIR individuals')
ax3.legend()

ax4.plot(t4, s4, lw=3, label='Total Number of Susceptible')
ax4.plot(t4, i4, lw=3, label='Total Number of Infective')
ax4.plot(t4, r4, lw=3, label='Recovered')
ax4.set_title('Susceptible and Recovered Populations- Period 4')
ax4.set_xlabel('Time /days')
ax4.set_ylabel('Total Number of SIR individuals')
ax4.legend()

fig.set_figheight(10)
fig.set_figwidth(15)

plt.show()

# %%
new_zealand['total_cases_shifted']= new_zealand.total_cases.shift(14)
new_zealand['active_cases_calc']= new_zealand['total_cases']-new_zealand['total_cases_shifted']
#new_zealand['susceptible']= new_zealand['population']-new_zealand['total_cases']
plt.figure(figsize=(12,5))
plt.plot(new_zealand.date[0:373],new_zealand['active_cases_calc'][0:373])
plt.title('Active cases')
plt.ylabel('Count')
plt.xlabel('days')
# Out:
# Text(0.5, 0, 'days')

# %% [markdown]
# #### Calculating the Accuracy of Predicted cases and Actual Case

# %%
d1 = {'actual':list(new_zealand['active_cases_calc'][14:57]),'predicted': list(i1) }
result1 = pd.DataFrame(data=d1)

# %% [markdown]
# ### Period 1

# %%
from sklearn.preprocessing import MinMaxScaler
scaler1 = MinMaxScaler()
result1[['actual','predicted']]= scaler1.fit_transform(result1[['actual','predicted']])

# %%
from sklearn.metrics import r2_score
print("Mean absolute error: %.2f" % np.mean(np.absolute(result1.predicted - result1.actual)))
print("Residual sum of squares (MSE): %.2f" % np.mean((result1.predicted - result1.actual) ** 2))
print(" R2 score",r2_score(result1.predicted,result1.actual))
plt.plot(t1,result1.actual, label='actual infected')
plt.plot(t1,result1.predicted, label='actual infected')
plt.legend()
plt.title('comparison')
# Out:
# Mean absolute error: 0.12
# Residual sum of squares (MSE): 0.02
#  R2 score 0.7946197886071532
# Text(0.5, 1.0, 'comparison')

# %% [markdown]
# ### Period 2

# %%
d2 = {'actual':list(new_zealand['active_cases_calc'][14:126]),'predicted': list(i2) }
result2 = pd.DataFrame(data=d2)

scaler2 = MinMaxScaler()
result2[['actual','predicted']]= scaler2.fit_transform(result2[['actual','predicted']])
print("Mean absolute error: %.2f" % np.mean(np.absolute(result2.predicted - result2.actual)))
print("Residual sum of squares (MSE): %.2f" % np.mean((result2.predicted - result2.actual) ** 2))
print(" R2 score",r2_score(result2.predicted,result2.actual))

plt.plot(t2,result2.actual, label='actual infected')
plt.plot(t2,result2.predicted, label='actual infected')
plt.legend()
plt.title('comparison')
# Out:
# Mean absolute error: 0.07
# Residual sum of squares (MSE): 0.01
#  R2 score 0.8514729283486423
# Text(0.5, 1.0, 'comparison')

# %% [markdown]
# ### Period 3

# %%
d3= {'actual':list(new_zealand['active_cases_calc'][57:125]),'predicted': list(i3) }
result3 = pd.DataFrame(data=d3)
scaler3 = MinMaxScaler()
result3[['actual','predicted']]= scaler3.fit_transform(result3[['actual','predicted']])
print("Mean absolute error: %.2f" % np.mean(np.absolute(result3.predicted - result3.actual)))
print("Residual sum of squares (MSE): %.2f" % np.mean((result3.predicted - result3.actual) ** 2))
print(" R2 score",r2_score(result3.predicted,result3.actual))
plt.plot(t3,result3.actual, label='actual infected')
plt.plot(t3,result3.predicted, label='actual infected')
plt.legend()
plt.title('comparison')
# Out:
# Mean absolute error: 0.36
# Residual sum of squares (MSE): 0.22
#  R2 score -1.2854949182449111
# Text(0.5, 1.0, 'comparison')

# %% [markdown]
# ### Period 4

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ### This complete notebook represents an exploratory data analysis (EDA) process to put together the patterns related to the current COIVD-19 pandemic. We have dealt with the covid data "linear-comprehensive-covid-data" and grouped only a single country New Zealand. The purpose of this study is to analyze the dataset and obtain important insights form it. As visual representations are flexible and easy to understand, the results or outputs produced in the form of graphs can help people comprehend the current situation insights easily. The dataset used may not be an updated version; hence the inferences may vary from time to time as graphs can be generated as the data increases. As the amount of data increases, the trends may change and lead to different inferences and solutions.
