# %% [markdown]
# ## NEW ZEALAND

# %% [markdown]
# ### The main purpose of Exploratory Data Analysis is to help look at the data before making any assumption, The Covid-19 pandemic is the most crucial health disaster that has surrounded the world for the past year. The following data helps us to understand the consequences of the COVID‐19 outbreak.

# %% [markdown]
# ### Importing required Libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

#import plotly.graph_objs as go
#import plotly.express as px
import seaborn as sns # data visualization library

# %% [markdown]
# #### Loading the Dataset

# %%
df = pd.read_csv("New-covid-data(NZ).csv")
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0        1803.987              NaN                597.029
# 1        1803.987              NaN                597.029
# 2        1803.987              NaN                597.029
# 3        1803.987              NaN                597.029
# 4        1803.987              NaN                597.029
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                 9.59             NaN           NaN                  37.746
# 1                 9.59             NaN           NaN                  37.746
# 2                 9.59             NaN           NaN                  37.746
# 3                 9.59             NaN           NaN                  37.746
# 4                 9.59             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
# [5 rows x 59 columns]

# %% [markdown]
# #### Exploratory Data Analysis

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
#        'new_vaccinations_smoothed', 'total_vaccinations_per_hundred',
#        'people_vaccinated_per_hundred', 'people_fully_vaccinated_per_hundred',
#        'new_vaccinations_smoothed_per_million', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index'],
#       dtype='object')

# %%
print("Shape of the Covid DataFrame Accross world:",df.shape,"\n")
# Out:
# Shape of the Covid DataFrame Accross world: (79678, 59)

# %% [markdown]
# ### CREATING A NEW DATAFRAME FOR THE NEW ZEALAND DATA

# %%
NZ_df = df.loc[df["location"] =="New Zealand"]
display(NZ_df.head())
NZ_df.shape
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 50789      NZL   Oceania  New Zealand  2020-02-28          1.0        1.0
# 50790      NZL   Oceania  New Zealand  2020-02-29          1.0        0.0
# 50791      NZL   Oceania  New Zealand  2020-03-01          1.0        0.0
# 50792      NZL   Oceania  New Zealand  2020-03-02          1.0        0.0
# 50793      NZL   Oceania  New Zealand  2020-03-03          1.0        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 50789                 NaN           NaN         NaN                  NaN  ...
# 50790                 NaN           NaN         NaN                  NaN  ...
# 50791                 NaN           NaN         NaN                  NaN  ...
# 50792                 NaN           NaN         NaN                  NaN  ...
# 50793                 NaN           NaN         NaN                  NaN  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 50789       36085.843              NaN                128.797
# 50790       36085.843              NaN                128.797
# 50791       36085.843              NaN                128.797
# 50792       36085.843              NaN                128.797
# 50793       36085.843              NaN                128.797
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 50789                 8.08            14.8          17.2
# 50790                 8.08            14.8          17.2
# 50791                 8.08            14.8          17.2
# 50792                 8.08            14.8          17.2
# 50793                 8.08            14.8          17.2
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 50789                     NaN                        2.61            82.29
# 50790                     NaN                        2.61            82.29
# 50791                     NaN                        2.61            82.29
# 50792                     NaN                        2.61            82.29
# 50793                     NaN                        2.61            82.29
#
#        human_development_index
# 50789                    0.931
# 50790                    0.931
# 50791                    0.931
# 50792                    0.931
# 50793                    0.931
#
# [5 rows x 59 columns]
# (403, 59)

# %%
NZ_df = NZ_df.reset_index()  #RESETS THE INDEX OF THE DF
NZ_df.drop('index', axis=1, inplace=True)

# %%
NZ_df.head()  #display the data to see if the index is reset
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      NZL   Oceania  New Zealand  2020-02-28          1.0        1.0
# 1      NZL   Oceania  New Zealand  2020-02-29          1.0        0.0
# 2      NZL   Oceania  New Zealand  2020-03-01          1.0        0.0
# 3      NZL   Oceania  New Zealand  2020-03-02          1.0        0.0
# 4      NZL   Oceania  New Zealand  2020-03-03          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0       36085.843              NaN                128.797
# 1       36085.843              NaN                128.797
# 2       36085.843              NaN                128.797
# 3       36085.843              NaN                128.797
# 4       36085.843              NaN                128.797
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                 8.08            14.8          17.2                     NaN
# 1                 8.08            14.8          17.2                     NaN
# 2                 8.08            14.8          17.2                     NaN
# 3                 8.08            14.8          17.2                     NaN
# 4                 8.08            14.8          17.2                     NaN
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index
# 0                        2.61            82.29                    0.931
# 1                        2.61            82.29                    0.931
# 2                        2.61            82.29                    0.931
# 3                        2.61            82.29                    0.931
# 4                        2.61            82.29                    0.931
#
# [5 rows x 59 columns]

# %%
NZ_df.info()  #info about the raw dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 403 entries, 0 to 402
# Data columns (total 59 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso_code                               403 non-null    object
#  1   continent                              403 non-null    object
#  2   location                               403 non-null    object
#  3   date                                   403 non-null    object
#  4   total_cases                            403 non-null    float64
#  5   new_cases                              403 non-null    float64
#  6   new_cases_smoothed                     398 non-null    float64
#  7   total_deaths                           373 non-null    float64
#  8   new_deaths                             373 non-null    float64
#  9   new_deaths_smoothed                    398 non-null    float64
#  10  total_cases_per_million                403 non-null    float64
#  11  new_cases_per_million                  403 non-null    float64
#  12  new_cases_smoothed_per_million         398 non-null    float64
#  13  total_deaths_per_million               373 non-null    float64
#  14  new_deaths_per_million                 373 non-null    float64
#  15  new_deaths_smoothed_per_million        398 non-null    float64
#  16  reproduction_rate                      377 non-null    float64
#  17  icu_patients                           0 non-null      float64
#  18  icu_patients_per_million               0 non-null      float64
#  19  hosp_patients                          0 non-null      float64
#  20  hosp_patients_per_million              0 non-null      float64
#  21  weekly_icu_admissions                  0 non-null      float64
#  22  weekly_icu_admissions_per_million      0 non-null      float64
#  23  weekly_hosp_admissions                 0 non-null      float64
#  24  weekly_hosp_admissions_per_million     0 non-null      float64
#  25  new_tests                              323 non-null    float64
#  26  total_tests                            354 non-null    float64
#  27  total_tests_per_thousand               354 non-null    float64
#  28  new_tests_per_thousand                 323 non-null    float64
#  29  new_tests_smoothed                     390 non-null    float64
#  30  new_tests_smoothed_per_thousand        390 non-null    float64
#  31  positive_rate                          390 non-null    float64
#  32  tests_per_case                         372 non-null    float64
#  33  tests_units                            397 non-null    object
#  34  total_vaccinations                     10 non-null     float64
#  35  people_vaccinated                      10 non-null     float64
#  36  people_fully_vaccinated                1 non-null      float64
#  37  new_vaccinations                       2 non-null      float64
#  38  new_vaccinations_smoothed              41 non-null     float64
#  39  total_vaccinations_per_hundred         10 non-null     float64
#  40  people_vaccinated_per_hundred          10 non-null     float64
#  41  people_fully_vaccinated_per_hundred    1 non-null      float64
#  42  new_vaccinations_smoothed_per_million  41 non-null     float64
#  43  stringency_index                       396 non-null    float64
#  44  population                             403 non-null    float64
#  45  population_density                     403 non-null    float64
#  46  median_age                             403 non-null    float64
#  47  aged_65_older                          403 non-null    float64
#  48  aged_70_older                          403 non-null    float64
#  49  gdp_per_capita                         403 non-null    float64
#  50  extreme_poverty                        0 non-null      float64
#  51  cardiovasc_death_rate                  403 non-null    float64
#  52  diabetes_prevalence                    403 non-null    float64
#  53  female_smokers                         403 non-null    float64
#  54  male_smokers                           403 non-null    float64
#  55  handwashing_facilities                 0 non-null      float64
#  56  hospital_beds_per_thousand             403 non-null    float64
#  57  life_expectancy                        403 non-null    float64
#  58  human_development_index                403 non-null    float64
# dtypes: float64(54), object(5)
# memory usage: 185.9+ KB

# %%
NZ_df.describe()
# Out:
#        total_cases   new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# count   403.000000  403.000000          398.000000    373.000000  373.000000
# mean   1723.729529    6.263027            6.291116     22.536193    0.069705
# std     599.711700   14.232270           13.217634      5.178731    0.359912
# min       1.000000   -2.000000            0.000000      1.000000    0.000000
# 25%    1504.000000    0.000000            1.571000     22.000000    0.000000
# 50%    1809.000000    2.000000            3.000000     25.000000    0.000000
# 75%    2136.000000    5.500000            4.535500     25.000000    0.000000
# max    2524.000000   89.000000           75.000000     26.000000    4.000000
#
#        new_deaths_smoothed  total_cases_per_million  new_cases_per_million  \
# count           398.000000               403.000000             403.000000
# mean              0.065349               357.454630               1.298727
# std               0.207174               124.363906               2.951405
# min               0.000000                 0.207000              -0.415000
# 25%               0.000000               311.889000               0.000000
# 50%               0.000000               375.137000               0.415000
# 75%               0.000000               442.948000               1.140500
# max               1.286000               523.409000              18.456000
#
#        new_cases_smoothed_per_million  total_deaths_per_million  ...  \
# count                      398.000000                373.000000  ...
# mean                         1.304545                  4.673236  ...
# std                          2.740977                  1.073968  ...
# min                          0.000000                  0.207000  ...
# 25%                          0.326000                  4.562000  ...
# 50%                          0.622000                  5.184000  ...
# 75%                          0.940500                  5.184000  ...
# max                         15.553000                  5.392000  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# count    4.030000e+02              0.0           4.030000e+02
# mean     3.608584e+04              NaN           1.287970e+02
# std      2.331201e-10              NaN           8.537111e-13
# min      3.608584e+04              NaN           1.287970e+02
# 25%      3.608584e+04              NaN           1.287970e+02
# 50%      3.608584e+04              NaN           1.287970e+02
# 75%      3.608584e+04              NaN           1.287970e+02
# max      3.608584e+04              NaN           1.287970e+02
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# count         4.030000e+02    4.030000e+02  4.030000e+02
# mean          8.080000e+00    1.480000e+01  1.720000e+01
# std           4.446412e-14    1.067139e-13  1.173853e-13
# min           8.080000e+00    1.480000e+01  1.720000e+01
# 25%           8.080000e+00    1.480000e+01  1.720000e+01
# 50%           8.080000e+00    1.480000e+01  1.720000e+01
# 75%           8.080000e+00    1.480000e+01  1.720000e+01
# max           8.080000e+00    1.480000e+01  1.720000e+01
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# count                     0.0                4.030000e+02     4.030000e+02
# mean                      NaN                2.610000e+00     8.229000e+01
# std                       NaN                8.892824e-15     6.260548e-13
# min                       NaN                2.610000e+00     8.229000e+01
# 25%                       NaN                2.610000e+00     8.229000e+01
# 50%                       NaN                2.610000e+00     8.229000e+01
# 75%                       NaN                2.610000e+00     8.229000e+01
# max                       NaN                2.610000e+00     8.229000e+01
#
#        human_development_index
# count             4.030000e+02
# mean              9.310000e-01
# std               2.000885e-15
# min               9.310000e-01
# 25%               9.310000e-01
# 50%               9.310000e-01
# 75%               9.310000e-01
# max               9.310000e-01
#
# [8 rows x 54 columns]

# %%
NZ_df.isnull().sum()   #Checking the count of NULL values in each column
# Out:
# iso_code                                   0
# continent                                  0
# location                                   0
# date                                       0
# total_cases                                0
# new_cases                                  0
# new_cases_smoothed                         5
# total_deaths                              30
# new_deaths                                30
# new_deaths_smoothed                        5
# total_cases_per_million                    0
# new_cases_per_million                      0
# new_cases_smoothed_per_million             5
# total_deaths_per_million                  30
# new_deaths_per_million                    30
# new_deaths_smoothed_per_million            5
# reproduction_rate                         26
# icu_patients                             403
# icu_patients_per_million                 403
# hosp_patients                            403
# hosp_patients_per_million                403
# weekly_icu_admissions                    403
# weekly_icu_admissions_per_million        403
# weekly_hosp_admissions                   403
# weekly_hosp_admissions_per_million       403
# new_tests                                 80
# total_tests                               49
# total_tests_per_thousand                  49
# new_tests_per_thousand                    80
# new_tests_smoothed                        13
# new_tests_smoothed_per_thousand           13
# positive_rate                             13
# tests_per_case                            31
# tests_units                                6
# total_vaccinations                       393
# people_vaccinated                        393
# people_fully_vaccinated                  402
# new_vaccinations                         401
# new_vaccinations_smoothed                362
# total_vaccinations_per_hundred           393
# people_vaccinated_per_hundred            393
# people_fully_vaccinated_per_hundred      402
# new_vaccinations_smoothed_per_million    362
# stringency_index                           7
# population                                 0
# population_density                         0
# median_age                                 0
# aged_65_older                              0
# aged_70_older                              0
# gdp_per_capita                             0
# extreme_poverty                          403
# cardiovasc_death_rate                      0
# diabetes_prevalence                        0
# female_smokers                             0
# male_smokers                               0
# handwashing_facilities                   403
# hospital_beds_per_thousand                 0
# life_expectancy                            0
# human_development_index                    0
# dtype: int64

# %%
print(NZ_df.population.value_counts())
print(NZ_df.population_density.value_counts())
print(NZ_df.aged_65_older.value_counts())
print(NZ_df.aged_70_older.value_counts())
print(NZ_df.median_age.value_counts())
# Out:
# 4822233.0    403
# Name: population, dtype: int64
# 18.206    403
# Name: population_density, dtype: int64
# 15.322    403
# Name: aged_65_older, dtype: int64
# 9.72    403
# Name: aged_70_older, dtype: int64
# 37.9    403
# Name: median_age, dtype: int64

# %% [markdown]
# #### Checking unique elements in thses columns

# %%
NZ_df['date']   #Checking the format of the date
# Out:
# 0      2020-02-28
# 1      2020-02-29
# 2      2020-03-01
# 3      2020-03-02
# 4      2020-03-03
#           ...
# 398    2021-04-01
# 399    2021-04-02
# 400    2021-04-03
# 401    2021-04-04
# 402    2021-04-05
# Name: date, Length: 403, dtype: object

# %% [markdown]
# ### Here we see that the data that we have is daily starting from 31 Dec 2019 to 14 Mar 2021 for a total of 381 days

# %% [markdown]
# ### Now we make a new data frame of only the important columns by dropping the others

# %%
NZ_process_df = NZ_df.drop(['iso_code', 'continent', 'handwashing_facilities', 'extreme_poverty', 'tests_per_case', 'tests_units', 'human_development_index','median_age','population',
                             'population_density','aged_65_older','aged_70_older','gdp_per_capita','cardiovasc_death_rate','diabetes_prevalence','female_smokers','male_smokers',
                            'hospital_beds_per_thousand','life_expectancy',  'total_vaccinations', 'people_vaccinated','people_fully_vaccinated', 'new_vaccinations' ,
                            'new_vaccinations_smoothed','total_vaccinations_per_hundred','people_vaccinated_per_hundred','people_fully_vaccinated_per_hundred',
                            'new_vaccinations_smoothed_per_million','icu_patients',  'icu_patients_per_million', 'hosp_patients'          
   ,'hosp_patients_per_million'       
   ,'weekly_icu_admissions'            
   ,'weekly_icu_admissions_per_million'  
   ,'weekly_hosp_admissions'
,'weekly_hosp_admissions_per_million'
                            ],axis = 1,inplace=False)
NZ_process_df.columns
# Out:
# Index(['location', 'date', 'total_cases', 'new_cases', 'new_cases_smoothed',
#        'total_deaths', 'new_deaths', 'new_deaths_smoothed',
#        'total_cases_per_million', 'new_cases_per_million',
#        'new_cases_smoothed_per_million', 'total_deaths_per_million',
#        'new_deaths_per_million', 'new_deaths_smoothed_per_million',
#        'reproduction_rate', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'stringency_index'],
#       dtype='object')

# %%
NZ_df.isnull().sum()
# Out:
# iso_code                                   0
# continent                                  0
# location                                   0
# date                                       0
# total_cases                                0
# new_cases                                  0
# new_cases_smoothed                         5
# total_deaths                              30
# new_deaths                                30
# new_deaths_smoothed                        5
# total_cases_per_million                    0
# new_cases_per_million                      0
# new_cases_smoothed_per_million             5
# total_deaths_per_million                  30
# new_deaths_per_million                    30
# new_deaths_smoothed_per_million            5
# reproduction_rate                         26
# icu_patients                             403
# icu_patients_per_million                 403
# hosp_patients                            403
# hosp_patients_per_million                403
# weekly_icu_admissions                    403
# weekly_icu_admissions_per_million        403
# weekly_hosp_admissions                   403
# weekly_hosp_admissions_per_million       403
# new_tests                                 80
# total_tests                               49
# total_tests_per_thousand                  49
# new_tests_per_thousand                    80
# new_tests_smoothed                        13
# new_tests_smoothed_per_thousand           13
# positive_rate                             13
# tests_per_case                            31
# tests_units                                6
# total_vaccinations                       393
# people_vaccinated                        393
# people_fully_vaccinated                  402
# new_vaccinations                         401
# new_vaccinations_smoothed                362
# total_vaccinations_per_hundred           393
# people_vaccinated_per_hundred            393
# people_fully_vaccinated_per_hundred      402
# new_vaccinations_smoothed_per_million    362
# stringency_index                           7
# population                                 0
# population_density                         0
# median_age                                 0
# aged_65_older                              0
# aged_70_older                              0
# gdp_per_capita                             0
# extreme_poverty                          403
# cardiovasc_death_rate                      0
# diabetes_prevalence                        0
# female_smokers                             0
# male_smokers                               0
# handwashing_facilities                   403
# hospital_beds_per_thousand                 0
# life_expectancy                            0
# human_development_index                    0
# dtype: int64

# %%
NZ_process_df.head()
# Out:
#       location        date  total_cases  new_cases  new_cases_smoothed  \
# 0  New Zealand  2020-02-28          1.0        1.0                 NaN
# 1  New Zealand  2020-02-29          1.0        0.0                 NaN
# 2  New Zealand  2020-03-01          1.0        0.0                 NaN
# 3  New Zealand  2020-03-02          1.0        0.0                 NaN
# 4  New Zealand  2020-03-03          1.0        0.0                 NaN
#
#    total_deaths  new_deaths  new_deaths_smoothed  total_cases_per_million  \
# 0           NaN         NaN                  NaN                    0.207
# 1           NaN         NaN                  NaN                    0.207
# 2           NaN         NaN                  NaN                    0.207
# 3           NaN         NaN                  NaN                    0.207
# 4           NaN         NaN                  NaN                    0.207
#
#    new_cases_per_million  ...  new_deaths_smoothed_per_million  \
# 0                  0.207  ...                              NaN
# 1                  0.000  ...                              NaN
# 2                  0.000  ...                              NaN
# 3                  0.000  ...                              NaN
# 4                  0.000  ...                              NaN
#
#    reproduction_rate  new_tests  total_tests  total_tests_per_thousand  \
# 0                NaN        NaN          NaN                       NaN
# 1                NaN        NaN          NaN                       NaN
# 2                NaN        NaN        225.0                     0.047
# 3                NaN       29.0        254.0                     0.053
# 4                NaN       26.0        280.0                     0.058
#
#    new_tests_per_thousand  new_tests_smoothed  \
# 0                     NaN                 NaN
# 1                     NaN                 NaN
# 2                     NaN                 NaN
# 3                   0.006                 NaN
# 4                   0.005                 NaN
#
#    new_tests_smoothed_per_thousand  positive_rate  stringency_index
# 0                              NaN            NaN             19.44
# 1                              NaN            NaN             19.44
# 2                              NaN            NaN             19.44
# 3                              NaN            NaN             19.44
# 4                              NaN            NaN             19.44
#
# [5 rows x 23 columns]

# %%
count = 0
for row in NZ_process_df['total_cases']:
    count = count + 1
    if row!=0:
        break
 
print(count)
# Out:
# 1

# %%
NZ_replace_initial = ['total_deaths', 'total_tests', 'total_cases', 'new_tests', 'new_cases',
     'positive_rate', 'new_deaths', 'new_tests_smoothed', 'new_deaths_smoothed', 'stringency_index']
Ger_replace_initial =  ['total_deaths', 'total_tests', 'total_cases', 'new_cases',
     'positive_rate', 'new_deaths', 'new_tests_smoothed', 'new_deaths_smoothed', 'stringency_index']

for i in NZ_replace_initial:
    s = pd.Series(NZ_df[i])
    NZ_process_df.loc[0:s.first_valid_index(),i] = 0.0

# %%
# replacing the missing values with mean 

replace_mean_list = ['total_cases', 'new_cases', 'new_cases_smoothed',
       'total_deaths', 'new_deaths', 'new_deaths_smoothed',
       'total_cases_per_million', 'new_cases_per_million',
       'new_cases_smoothed_per_million', 'total_deaths_per_million',
       'new_deaths_per_million', 'new_deaths_smoothed_per_million',
       'new_tests', 'total_tests', 'total_tests_per_thousand',
       'new_tests_per_thousand', 'new_tests_smoothed',
       'new_tests_smoothed_per_thousand', 'positive_rate', 'stringency_index','reproduction_rate']

replace_mean_list_ger = ['total_cases', 'new_cases', 'new_cases_smoothed',
       'total_deaths', 'new_deaths', 'new_deaths_smoothed',
       'total_cases_per_million', 'new_cases_per_million',
       'new_cases_smoothed_per_million', 'total_deaths_per_million',
       'new_deaths_per_million', 'new_deaths_smoothed_per_million',
       'total_tests', 'total_tests_per_thousand',
       'new_tests_smoothed',
       'new_tests_smoothed_per_thousand', 'positive_rate', 'stringency_index','reproduction_rate']

for i in replace_mean_list:
    NZ_process_df[i].fillna(NZ_process_df[i].mean(), inplace=True)
      
NZ_process_df.to_csv('NZ.csv', index=False)

# %%
NZ_process_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 403 entries, 0 to 402
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   location                         403 non-null    object
#  1   date                             403 non-null    object
#  2   total_cases                      403 non-null    float64
#  3   new_cases                        403 non-null    float64
#  4   new_cases_smoothed               403 non-null    float64
#  5   total_deaths                     403 non-null    float64
#  6   new_deaths                       403 non-null    float64
#  7   new_deaths_smoothed              403 non-null    float64
#  8   total_cases_per_million          403 non-null    float64
#  9   new_cases_per_million            403 non-null    float64
#  10  new_cases_smoothed_per_million   403 non-null    float64
#  11  total_deaths_per_million         403 non-null    float64
#  12  new_deaths_per_million           403 non-null    float64
#  13  new_deaths_smoothed_per_million  403 non-null    float64
#  14  reproduction_rate                403 non-null    float64
#  15  new_tests                        403 non-null    float64
#  16  total_tests                      403 non-null    float64
#  17  total_tests_per_thousand         403 non-null    float64
#  18  new_tests_per_thousand           403 non-null    float64
#  19  new_tests_smoothed               403 non-null    float64
#  20  new_tests_smoothed_per_thousand  403 non-null    float64
#  21  positive_rate                    403 non-null    float64
#  22  stringency_index                 403 non-null    float64
# dtypes: float64(21), object(2)
# memory usage: 72.5+ KB

# %%
NZ_process_df.describe()
# Out:
#        total_cases   new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# count   403.000000  403.000000          403.000000    403.000000  403.000000
# mean   1723.727047    6.260546            6.291116     20.856079    0.062035
# std     599.718848   14.233277           13.135177      7.745911    0.343559
# min       0.000000   -2.000000            0.000000      0.000000    0.000000
# 25%    1504.000000    0.000000            1.571000     22.000000    0.000000
# 50%    1809.000000    2.000000            3.000000     25.000000    0.000000
# 75%    2136.000000    5.500000            4.714000     25.000000    0.000000
# max    2524.000000   89.000000           75.000000     26.000000    4.000000
#
#        new_deaths_smoothed  total_cases_per_million  new_cases_per_million  \
# count           403.000000               403.000000             403.000000
# mean              0.064538               357.454630               1.298727
# std               0.206009               124.363906               2.951405
# min               0.000000                 0.207000              -0.415000
# 25%               0.000000               311.889000               0.000000
# 50%               0.000000               375.137000               0.415000
# 75%               0.000000               442.948000               1.140500
# max               1.286000               523.409000              18.456000
#
#        new_cases_smoothed_per_million  total_deaths_per_million  ...  \
# count                      403.000000                403.000000  ...
# mean                         1.304545                  4.673236  ...
# std                          2.723878                  1.033118  ...
# min                          0.000000                  0.207000  ...
# 25%                          0.326000                  4.562000  ...
# 50%                          0.622000                  5.184000  ...
# 75%                          0.978000                  5.184000  ...
# max                         15.553000                  5.392000  ...
#
#        new_deaths_smoothed_per_million  reproduction_rate     new_tests  \
# count                       403.000000         403.000000    403.000000
# mean                          0.013565           0.884536   4897.610429
# std                           0.042670           0.286337   3510.423071
# min                           0.000000           0.190000      0.000000
# 25%                           0.000000           0.795000   2697.000000
# 50%                           0.000000           0.884536   4897.610429
# 75%                           0.000000           1.060000   5957.500000
# max                           0.267000           1.950000  25005.000000
#
#         total_tests  total_tests_per_thousand  new_tests_per_thousand  \
# count  4.030000e+02                403.000000              403.000000
# mean   7.592914e+05                158.346124                1.025090
# std    5.392457e+05                111.268692                0.722575
# min    0.000000e+00                  0.047000                0.005000
# 25%    2.900070e+05                 61.145500                0.563500
# 50%    7.592914e+05                158.346124                1.025090
# 75%    1.152224e+06                238.939500                1.235500
# max    1.902915e+06                394.613000                5.185000
#
#        new_tests_smoothed  new_tests_smoothed_per_thousand  positive_rate  \
# count          403.000000                       403.000000     403.000000
# mean          4731.358396                         1.003821       0.002190
# std           2949.331177                         0.593278       0.005774
# min              0.000000                         0.007000       0.000000
# 25%           2966.000000                         0.655000       0.000000
# 50%           4477.000000                         0.944000       0.001000
# 75%           5740.000000                         1.190500       0.001000
# max          20966.000000                         4.348000       0.040000
#
#        stringency_index
# count        403.000000
# mean          37.510227
# std           24.314152
# min            0.000000
# 25%           22.220000
# 50%           22.220000
# 75%           39.350000
# max           96.300000
#
# [8 rows x 21 columns]

# %%
NZ_process_df.corr()
# Out:
#                                  total_cases  new_cases  new_cases_smoothed  \
# total_cases                         1.000000  -0.324952           -0.295514
# new_cases                          -0.324952   1.000000            0.894175
# new_cases_smoothed                 -0.295514   0.894175            1.000000
# total_deaths                        0.897255  -0.554212           -0.583710
# new_deaths                         -0.069786   0.052644            0.157895
# new_deaths_smoothed                -0.124524   0.083381            0.188004
# total_cases_per_million             1.000000  -0.324958           -0.295518
# new_cases_per_million              -0.325481   0.999994            0.894239
# new_cases_smoothed_per_million     -0.295513   0.894174            1.000000
# total_deaths_per_million            0.459224  -0.652447           -0.837044
# new_deaths_per_million             -0.125305   0.090076            0.188463
# new_deaths_smoothed_per_million    -0.136110   0.082285            0.188774
# reproduction_rate                  -0.019076   0.419474            0.315158
# new_tests                           0.380674  -0.061431           -0.066383
# total_tests                         0.794049  -0.283572           -0.284978
# total_tests_per_thousand            0.778510  -0.288132           -0.286586
# new_tests_per_thousand              0.355204  -0.066933           -0.067378
# new_tests_smoothed                  0.441774  -0.114910           -0.092560
# new_tests_smoothed_per_thousand     0.347114  -0.133927           -0.102945
# positive_rate                      -0.422780   0.900414            0.927365
# stringency_index                   -0.303718   0.562315            0.619740
#
#                                  total_deaths  new_deaths  \
# total_cases                          0.897255   -0.069786
# new_cases                           -0.554212    0.052644
# new_cases_smoothed                  -0.583710    0.157895
# total_deaths                         1.000000   -0.149003
# new_deaths                          -0.149003    1.000000
# new_deaths_smoothed                 -0.216449    0.581068
# total_cases_per_million              0.897255   -0.069787
# new_cases_per_million               -0.554726    0.052615
# new_cases_smoothed_per_million      -0.583709    0.157900
# total_deaths_per_million             0.644534   -0.292715
# new_deaths_per_million              -0.207606    0.988323
# new_deaths_smoothed_per_million     -0.227494    0.580822
# reproduction_rate                   -0.138746   -0.189990
# new_tests                            0.367874   -0.007793
# total_tests                          0.677106   -0.171892
# total_tests_per_thousand             0.661963   -0.174198
# new_tests_per_thousand               0.343480   -0.010213
# new_tests_smoothed                   0.442523   -0.023330
# new_tests_smoothed_per_thousand      0.354360   -0.030969
# positive_rate                       -0.662569    0.113153
# stringency_index                    -0.458870    0.348052
#
#                                  new_deaths_smoothed  total_cases_per_million  \
# total_cases                                -0.124524                 1.000000
# new_cases                                   0.083381                -0.324958
# new_cases_smoothed                          0.188004                -0.295518
# total_deaths                               -0.216449                 0.897255
# new_deaths                                  0.581068                -0.069787
# new_deaths_smoothed                         1.000000                -0.124526
# total_cases_per_million                    -0.124526                 1.000000
# new_cases_per_million                       0.083333                -0.325486
# new_cases_smoothed_per_million              0.188012                -0.295517
# total_deaths_per_million                   -0.442095                 0.459230
# new_deaths_per_million                      0.574562                -0.125306
# new_deaths_smoothed_per_million             0.999377                -0.136112
# reproduction_rate                          -0.345768                -0.019077
# new_tests                                  -0.026593                 0.380673
# total_tests                                -0.295668                 0.794053
# total_tests_per_thousand                   -0.299643                 0.778519
# new_tests_per_thousand                     -0.030851                 0.355209
# new_tests_smoothed                         -0.032025                 0.441773
# new_tests_smoothed_per_thousand            -0.045014                 0.347118
# positive_rate                               0.144160                -0.422786
# stringency_index                            0.589969                -0.303728
#
#                                  new_cases_per_million  \
# total_cases                                  -0.325481
# new_cases                                     0.999994
# new_cases_smoothed                            0.894239
# total_deaths                                 -0.554726
# new_deaths                                    0.052615
# new_deaths_smoothed                           0.083333
# total_cases_per_million                      -0.325486
# new_cases_per_million                         1.000000
# new_cases_smoothed_per_million                0.894238
# total_deaths_per_million                     -0.652495
# new_deaths_per_million                        0.090079
# new_deaths_smoothed_per_million               0.082292
# reproduction_rate                             0.419501
# new_tests                                    -0.061682
# total_tests                                  -0.283844
# total_tests_per_thousand                     -0.288158
# new_tests_per_thousand                       -0.066941
# new_tests_smoothed                           -0.115206
# new_tests_smoothed_per_thousand              -0.133944
# positive_rate                                 0.900413
# stringency_index                              0.562089
#
#                                  new_cases_smoothed_per_million  \
# total_cases                                           -0.295513
# new_cases                                              0.894174
# new_cases_smoothed                                     1.000000
# total_deaths                                          -0.583709
# new_deaths                                             0.157900
# new_deaths_smoothed                                    0.188012
# total_cases_per_million                               -0.295517
# new_cases_per_million                                  0.894238
# new_cases_smoothed_per_million                         1.000000
# total_deaths_per_million                              -0.837046
# new_deaths_per_million                                 0.188467
# new_deaths_smoothed_per_million                        0.188783
# reproduction_rate                                      0.315147
# new_tests                                             -0.066376
# total_tests                                           -0.284980
# total_tests_per_thousand                              -0.286588
# new_tests_per_thousand                                -0.067372
# new_tests_smoothed                                    -0.092555
# new_tests_smoothed_per_thousand                       -0.102940
# positive_rate                                          0.927361
# stringency_index                                       0.619748
#
#                                  total_deaths_per_million  ...  \
# total_cases                                      0.459224  ...
# new_cases                                       -0.652447  ...
# new_cases_smoothed                              -0.837044  ...
# total_deaths                                     0.644534  ...
# new_deaths                                      -0.292715  ...
# new_deaths_smoothed                             -0.442095  ...
# total_cases_per_million                          0.459230  ...
# new_cases_per_million                           -0.652495  ...
# new_cases_smoothed_per_million                  -0.837046  ...
# total_deaths_per_million                         1.000000  ...
# new_deaths_per_million                          -0.321448  ...
# new_deaths_smoothed_per_million                 -0.442945  ...
# reproduction_rate                                0.022345  ...
# new_tests                                        0.164111  ...
# total_tests                                      0.579660  ...
# total_tests_per_thousand                         0.583079  ...
# new_tests_per_thousand                           0.166708  ...
# new_tests_smoothed                               0.200714  ...
# new_tests_smoothed_per_thousand                  0.207147  ...
# positive_rate                                   -0.754149  ...
# stringency_index                                -0.697393  ...
#
#                                  new_deaths_smoothed_per_million  \
# total_cases                                            -0.136110
# new_cases                                               0.082285
# new_cases_smoothed                                      0.188774
# total_deaths                                           -0.227494
# new_deaths                                              0.580822
# new_deaths_smoothed                                     0.999377
# total_cases_per_million                                -0.136112
# new_cases_per_million                                   0.082292
# new_cases_smoothed_per_million                          0.188783
# total_deaths_per_million                               -0.442945
# new_deaths_per_million                                  0.575075
# new_deaths_smoothed_per_million                         1.000000
# reproduction_rate                                      -0.345919
# new_tests                                              -0.032209
# total_tests                                            -0.301510
# total_tests_per_thousand                               -0.303300
# new_tests_per_thousand                                 -0.033197
# new_tests_smoothed                                     -0.038527
# new_tests_smoothed_per_thousand                        -0.045204
# positive_rate                                           0.143477
# stringency_index                                        0.587207
#
#                                  reproduction_rate  new_tests  total_tests  \
# total_cases                              -0.019076   0.380674     0.794049
# new_cases                                 0.419474  -0.061431    -0.283572
# new_cases_smoothed                        0.315158  -0.066383    -0.284978
# total_deaths                             -0.138746   0.367874     0.677106
# new_deaths                               -0.189990  -0.007793    -0.171892
# new_deaths_smoothed                      -0.345768  -0.026593    -0.295668
# total_cases_per_million                  -0.019077   0.380673     0.794053
# new_cases_per_million                     0.419501  -0.061682    -0.283844
# new_cases_smoothed_per_million            0.315147  -0.066376    -0.284980
# total_deaths_per_million                  0.022345   0.164111     0.579660
# new_deaths_per_million                   -0.157972  -0.033843    -0.201369
# new_deaths_smoothed_per_million          -0.345919  -0.032209    -0.301510
# reproduction_rate                         1.000000   0.184353     0.216123
# new_tests                                 0.184353   1.000000     0.331961
# total_tests                               0.216123   0.331961     1.000000
# total_tests_per_thousand                  0.217332   0.323741     0.995028
# new_tests_per_thousand                    0.186066   0.992642     0.320777
# new_tests_smoothed                        0.166183   0.732542     0.385343
# new_tests_smoothed_per_thousand           0.171255   0.702510     0.343889
# positive_rate                             0.369583  -0.185452    -0.343591
# stringency_index                         -0.051631   0.163509    -0.422677
#
#                                  total_tests_per_thousand  \
# total_cases                                      0.778510
# new_cases                                       -0.288132
# new_cases_smoothed                              -0.286586
# total_deaths                                     0.661963
# new_deaths                                      -0.174198
# new_deaths_smoothed                             -0.299643
# total_cases_per_million                          0.778519
# new_cases_per_million                           -0.288158
# new_cases_smoothed_per_million                  -0.286588
# total_deaths_per_million                         0.583079
# new_deaths_per_million                          -0.202564
# new_deaths_smoothed_per_million                 -0.303300
# reproduction_rate                                0.217332
# new_tests                                        0.323741
# total_tests                                      0.995028
# total_tests_per_thousand                         1.000000
# new_tests_per_thousand                           0.322380
# new_tests_smoothed                               0.375827
# new_tests_smoothed_per_thousand                  0.345490
# positive_rate                                   -0.348164
# stringency_index                                -0.433375
#
#                                  new_tests_per_thousand  new_tests_smoothed  \
# total_cases                                    0.355204            0.441774
# new_cases                                     -0.066933           -0.114910
# new_cases_smoothed                            -0.067378           -0.092560
# total_deaths                                   0.343480            0.442523
# new_deaths                                    -0.010213           -0.023330
# new_deaths_smoothed                           -0.030851           -0.032025
# total_cases_per_million                        0.355209            0.441773
# new_cases_per_million                         -0.066941           -0.115206
# new_cases_smoothed_per_million                -0.067372           -0.092555
# total_deaths_per_million                       0.166708            0.200714
# new_deaths_per_million                        -0.034590           -0.052013
# new_deaths_smoothed_per_million               -0.033197           -0.038527
# reproduction_rate                              0.186066            0.166183
# new_tests                                      0.992642            0.732542
# total_tests                                    0.320777            0.385343
# total_tests_per_thousand                       0.322380            0.375827
# new_tests_per_thousand                         1.000000            0.720610
# new_tests_smoothed                             0.720610            1.000000
# new_tests_smoothed_per_thousand                0.707269            0.970079
# positive_rate                                 -0.191335           -0.242647
# stringency_index                               0.152602            0.157294
#
#                                  new_tests_smoothed_per_thousand  \
# total_cases                                             0.347114
# new_cases                                              -0.133927
# new_cases_smoothed                                     -0.102945
# total_deaths                                            0.354360
# new_deaths                                             -0.030969
# new_deaths_smoothed                                    -0.045014
# total_cases_per_million                                 0.347118
# new_cases_per_million                                  -0.133944
# new_cases_smoothed_per_million                         -0.102940
# total_deaths_per_million                                0.207147
# new_deaths_per_million                                 -0.053706
# new_deaths_smoothed_per_million                        -0.045204
# reproduction_rate                                       0.171255
# new_tests                                               0.702510
# total_tests                                             0.343889
# total_tests_per_thousand                                0.345490
# new_tests_per_thousand                                  0.707269
# new_tests_smoothed                                      0.970079
# new_tests_smoothed_per_thousand                         1.000000
# positive_rate                                          -0.264495
# stringency_index                                        0.130623
#
#                                  positive_rate  stringency_index
# total_cases                          -0.422780         -0.303718
# new_cases                             0.900414          0.562315
# new_cases_smoothed                    0.927365          0.619740
# total_deaths                         -0.662569         -0.458870
# new_deaths                            0.113153          0.348052
# new_deaths_smoothed                   0.144160          0.589969
# total_cases_per_million              -0.422786         -0.303728
# new_cases_per_million                 0.900413          0.562089
# new_cases_smoothed_per_million        0.927361          0.619748
# total_deaths_per_million             -0.754149         -0.697393
# new_deaths_per_million                0.162754          0.363278
# new_deaths_smoothed_per_million       0.143477          0.587207
# reproduction_rate                     0.369583         -0.051631
# new_tests                            -0.185452          0.163509
# total_tests                          -0.343591         -0.422677
# total_tests_per_thousand             -0.348164         -0.433375
# new_tests_per_thousand               -0.191335          0.152602
# new_tests_smoothed                   -0.242647          0.157294
# new_tests_smoothed_per_thousand      -0.264495          0.130623
# positive_rate                         1.000000          0.560374
# stringency_index                      0.560374          1.000000
#
# [21 rows x 21 columns]

# %% [markdown]
# ### Plotting the correlation matrix

# %%
fig, ax = plt.subplots(figsize=(20,20))         # Sample figsize in inches
sns.heatmap(NZ_process_df.corr(), annot=True , ax = ax , cmap = 'RdYlGn', center=0)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Few insights from the Data

# %% [markdown]
# ##### Time series plots for some important varibles

# %%
import matplotlib.ticker as ticker  

fig,ax =  plt.subplots( 2, 2,  figsize = ( 20, 10)) 

sns.lineplot(x="date", y="total_deaths",data=NZ_process_df,ax =ax[0][0],color = 'r')
ax[0][0].xaxis.set_major_locator(ticker.MultipleLocator(30)) 
ax[0][0].tick_params(labelrotation = 45) 

sns.lineplot(x="date", y="new_deaths_smoothed",data=NZ_process_df,ax =ax[0][1],color = 'g')
ax[0][1].xaxis.set_major_locator(ticker.MultipleLocator(30)) 
ax[0][1].tick_params(labelrotation = 45) 

sns.lineplot(x="date", y="new_cases",data=NZ_process_df,ax =ax[1][0],color = 'b')
ax[1][0].xaxis.set_major_locator(ticker.MultipleLocator(30)) 
ax[1][0].tick_params(labelrotation = 45) 

sns.lineplot(x="date", y="stringency_index",data=NZ_process_df,ax =ax[1][1],color = 'y')
ax[1][1].xaxis.set_major_locator(ticker.MultipleLocator(30)) 
ax[1][1].tick_params(labelrotation = 45)

# %%
import matplotlib.ticker as ticker  

fig,ax =  plt.subplots( 2, 2,  figsize = ( 20, 10)) 

sns.lineplot(x="date", y="total_deaths",data=NZ_df,ax =ax[0][0],color = 'r')
ax[0][0].xaxis.set_major_locator(ticker.MultipleLocator(30)) 
ax[0][0].tick_params(labelrotation = 45) 

sns.lineplot(x="date", y="new_deaths_smoothed",data=NZ_df,ax =ax[0][1],color = 'g')
ax[0][1].xaxis.set_major_locator(ticker.MultipleLocator(30)) 
ax[0][1].tick_params(labelrotation = 45) 

sns.lineplot(x="date", y="new_cases",data=NZ_df,ax =ax[1][0],color = 'b')
ax[1][0].xaxis.set_major_locator(ticker.MultipleLocator(30)) 
ax[1][0].tick_params(labelrotation = 45) 

sns.lineplot(x="date", y="stringency_index",data=NZ_df,ax =ax[1][1],color = 'y')
ax[1][1].xaxis.set_major_locator(ticker.MultipleLocator(30)) 
ax[1][1].tick_params(labelrotation = 45)

# %% [markdown]
# ##### We observe that there were many deaths in March-April whereas the situation was nealy under control during the period of May-Jul.

# %%
fig, ax = plt.subplots(figsize=(20,6))
sns.lineplot(x="date", y="new_cases",sizes=(10, 10),data=NZ_df,ax =ax)
plt.xticks(rotation=45);
fig.tight_layout(pad = 1.2)
ax.xaxis.set_major_locator(ticker.MultipleLocator(7))

# %%
NZ_df.hist(column='new_tests', bins='auto')
plt.xlabel('New Tests')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
fig,ax =  plt.subplots( 2, 2,  figsize = ( 20, 10)) 

sns.lineplot(x="date", y="new_cases",data=NZ_process_df,ax =ax[0][0],color = 'r')
ax[0][0].xaxis.set_major_locator(ticker.MultipleLocator(30)) 
ax[0][0].tick_params(labelrotation = 45) 

sns.lineplot(x="date", y="total_cases",data=NZ_process_df,ax =ax[0][1],color = 'g')
ax[0][1].xaxis.set_major_locator(ticker.MultipleLocator(30)) 
ax[0][1].tick_params(labelrotation = 45) 

sns.lineplot(x="date", y="new_tests_smoothed",data=NZ_process_df,ax =ax[1][0],color = 'b')
ax[1][0].xaxis.set_major_locator(ticker.MultipleLocator(30)) 
ax[1][0].tick_params(labelrotation = 45) 

sns.lineplot(x="date", y="total_tests",data=NZ_process_df,ax =ax[1][1],color = 'y')
ax[1][1].xaxis.set_major_locator(ticker.MultipleLocator(30)) 
ax[1][1].tick_params(labelrotation = 45)

# %% [markdown]
# ### Time Period of First wave in New Zealand

# %%
fig,ax =  plt.subplots( 2, 2,  figsize = ( 20, 10)) 

sns.lineplot(x="date", y="new_cases",data=NZ_process_df,ax =ax[0][0],color = 'r')
ax[0][0].xaxis.set_major_locator(ticker.MultipleLocator(30)) 
ax[0][0].tick_params(labelrotation = 45)
ax[0][0].annotate('FIRST WAVE: ~45 DAYS', xy=(40, 80), xytext=(80, 88),
            arrowprops=dict(facecolor='black', shrink=0.05))
# Out:
# Text(80, 88, 'FIRST WAVE: ~45 DAYS')

# %% [markdown]
# ## Part-II Model Development

# %% [markdown]
# *  Methodology Used:
# * First we tried implementing Agent based Model for predicing the New Cases in New Zealand, but due to insufficient data about the pandemic, time constraints and lack of resources for Implementation of Agent Based Modelling we shifted our focus on Implementing Multivariate Linear Regression.
# * We divided the dataset into two parts
#        * Nearly 10 months for Model Development
#        * Last 2 months for Predicting the impact of coronavirus and the number of new cases per day.
# * Further Model Evaluation was done by using
#         * R2 score,MSE, MAE
#         * Distribution plot of Actual vs Predicted cases
#         * Comparison of Predicted new cases vs Actual New Cases for Last 2 months.

# %%
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import scale
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import make_pipeline

# %%
NZ_process_df_model = NZ_process_df.iloc[0:320]
NZ_process_df_predict = NZ_process_df.iloc[320:]

# %% [markdown]
# ### Feature Selection & Data splitting for First 8 months

# %% [markdown]
# ##### Feature Selection for New Zealand

# %%
y_data_NZ = NZ_process_df_model['new_cases_smoothed']      #new cases
x_data_NZ = NZ_process_df_model[['total_cases','total_deaths', 'new_deaths', 'new_deaths_smoothed'
  ,'new_tests', 'total_tests', 'new_tests_smoothed' , 'positive_rate', 'stringency_index']]

x_train_NZ, x_test_NZ, y_train_NZ, y_test_NZ = train_test_split(x_data_NZ, y_data_NZ, test_size=0.22, random_state=0)

print("number of test samples :", x_test_NZ.shape[0])
print("number of training samples:",x_train_NZ.shape[0])
#x_data.head(5)
# Out:
# number of test samples : 71
# number of training samples: 249

# %% [markdown]
# ###  Model Training

# %%
lm_NZ = LinearRegression()
lm_NZ.fit(x_train_NZ, y_train_NZ)
Y_hat_NZ=lm_NZ.predict(x_test_NZ)

# %% [markdown]
# ## Model Evaluation

# %%
print ('Coefficients: ', lm_NZ.coef_)
print ('Intercept: ' , lm_NZ.intercept_)
print("\nR2 Score for New Zealand model")
print('Train score :',lm_NZ.score(x_train_NZ, y_train_NZ))
print('Test score :', lm_NZ.score(x_test_NZ, y_test_NZ) )
# Out:
# Coefficients:  [ 2.62848344e-02 -1.72025215e+00  1.10428215e-01 -9.10822135e+00
#  -6.93518639e-05 -7.15540678e-06  6.11947654e-04  1.48563312e+03
#   3.54167604e-02]
# Intercept:  -2.816530854533755
#
# R2 Score for New Zealand model
# Train score : 0.9483380405511445
# Test score : 0.8992902751743972

# %% [markdown]
# ### Distribution Plot for Model Evaluation

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))

Y_hat_NZ=lm_NZ.predict(x_train_NZ)
ax1 = sns.distplot(y_data_NZ, hist=False, color="r", label="Actual Value")
sns.distplot(Y_hat_NZ, hist=False, color="b", label="Fitted Values" , ax=ax1)


plt.title('Actual vs Fitted Values of New cases for New Zealand')
plt.xlabel('New cases')
plt.ylabel('Proportion of New cases')

plt.show()
plt.close()
# Out:
# C:\Users\dipti juhi\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\dipti juhi\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Conclusion:
# 1. Earlier implemention of Agent based Model for predicing the New Cases in New Zealand was tried, but due to lack of Features required for ABM implemention in currently available datasets and lack of resources for Implementation of Agent Based Modelling we shifted our focus on Implementing Multivariate Linear Regression.
# 2. A detailed Exploratory Data Analysis was performed on the New Zealand Covid-19 data and prediction of new cases during 2nd wave was done by using Multi-Variate Linear Regression Model.
# 3. Further the model was evaluated using different evaluation metrices and was tested for different countries as well.(such as Germany, Slovakia)
# 4. Then the Prediction of new covid 19 cases in New Zealand & Germany during 2nd wave(i.e Last 2 months of our dataset) was done.
