# %% [markdown]
# # NEW ZEALAND EDA

# %% [markdown]
# The main purpose of Exploratory Data Analysis is to help look at the data before making any assumption, The Covid-19 pandemic is the most crucial health disaster that has surrounded the world for the past year. The following data helps us to understand the consequences of the COVID‐19 outbreak.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("owid-covid-data.csv")
df.head()
# Out:
#   iso_code      continent location        date  total_cases  new_cases  \
# 0      ABW  North America    Aruba  2020-03-13          2.0        2.0
# 1      ABW  North America    Aruba  2020-03-19          NaN        NaN
# 2      ABW  North America    Aruba  2020-03-20          4.0        2.0
# 3      ABW  North America    Aruba  2020-03-21          NaN        NaN
# 4      ABW  North America    Aruba  2020-03-22          NaN        NaN
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           0.0         0.0                  NaN  ...
# 1               0.286           NaN         NaN                  0.0  ...
# 2               0.286           0.0         0.0                  0.0  ...
# 3               0.286           NaN         NaN                  0.0  ...
# 4               0.286           NaN         NaN                  0.0  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0       35973.781              NaN                    NaN
# 1       35973.781              NaN                    NaN
# 2       35973.781              NaN                    NaN
# 3       35973.781              NaN                    NaN
# 4       35973.781              NaN                    NaN
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                11.62             NaN           NaN                     NaN
# 1                11.62             NaN           NaN                     NaN
# 2                11.62             NaN           NaN                     NaN
# 3                11.62             NaN           NaN                     NaN
# 4                11.62             NaN           NaN                     NaN
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index
# 0                         NaN            76.29                      NaN
# 1                         NaN            76.29                      NaN
# 2                         NaN            76.29                      NaN
# 3                         NaN            76.29                      NaN
# 4                         NaN            76.29                      NaN
#
# [5 rows x 41 columns]

# %%
x = df.groupby(df.location)
new_zealand= x.get_group("New Zealand")
new_zealand
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 34882      NZL   Oceania  New Zealand  2019-12-31          0.0        0.0
# 34883      NZL   Oceania  New Zealand  2020-01-01          0.0        0.0
# 34884      NZL   Oceania  New Zealand  2020-01-02          0.0        0.0
# 34885      NZL   Oceania  New Zealand  2020-01-03          0.0        0.0
# 34886      NZL   Oceania  New Zealand  2020-01-04          0.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 35167      NZL   Oceania  New Zealand  2020-10-11       1515.0        1.0
# 35168      NZL   Oceania  New Zealand  2020-10-12       1515.0        0.0
# 35169      NZL   Oceania  New Zealand  2020-10-13       1516.0        1.0
# 35170      NZL   Oceania  New Zealand  2020-10-14       1518.0        2.0
# 35171      NZL   Oceania  New Zealand  2020-10-15       1520.0        2.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 34882                 NaN           0.0         0.0                  NaN  ...
# 34883                 NaN           0.0         0.0                  NaN  ...
# 34884                 NaN           0.0         0.0                  NaN  ...
# 34885                 NaN           0.0         0.0                  NaN  ...
# 34886                 NaN           0.0         0.0                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 35167               2.429          25.0         0.0                  0.0  ...
# 35168               2.286          25.0         0.0                  0.0  ...
# 35169               2.000          25.0         0.0                  0.0  ...
# 35170               1.857          25.0         0.0                  0.0  ...
# 35171               1.714          25.0         0.0                  0.0  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 34882       36085.843              NaN                128.797
# 34883       36085.843              NaN                128.797
# 34884       36085.843              NaN                128.797
# 34885       36085.843              NaN                128.797
# 34886       36085.843              NaN                128.797
# ...               ...              ...                    ...
# 35167       36085.843              NaN                128.797
# 35168       36085.843              NaN                128.797
# 35169       36085.843              NaN                128.797
# 35170       36085.843              NaN                128.797
# 35171       36085.843              NaN                128.797
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 34882                 8.08            14.8          17.2
# 34883                 8.08            14.8          17.2
# 34884                 8.08            14.8          17.2
# 34885                 8.08            14.8          17.2
# 34886                 8.08            14.8          17.2
# ...                    ...             ...           ...
# 35167                 8.08            14.8          17.2
# 35168                 8.08            14.8          17.2
# 35169                 8.08            14.8          17.2
# 35170                 8.08            14.8          17.2
# 35171                 8.08            14.8          17.2
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 34882                     NaN                        2.61            82.29
# 34883                     NaN                        2.61            82.29
# 34884                     NaN                        2.61            82.29
# 34885                     NaN                        2.61            82.29
# 34886                     NaN                        2.61            82.29
# ...                       ...                         ...              ...
# 35167                     NaN                        2.61            82.29
# 35168                     NaN                        2.61            82.29
# 35169                     NaN                        2.61            82.29
# 35170                     NaN                        2.61            82.29
# 35171                     NaN                        2.61            82.29
#
#        human_development_index
# 34882                    0.917
# 34883                    0.917
# 34884                    0.917
# 34885                    0.917
# 34886                    0.917
# ...                        ...
# 35167                    0.917
# 35168                    0.917
# 35169                    0.917
# 35170                    0.917
# 35171                    0.917
#
# [290 rows x 41 columns]

# %% [markdown]
# Percentage of missing values for each column

# %%
def missing(dff):
    print (round((dff.isnull().sum() * 100/ len(dff)),2).sort_values(ascending=False))
    
missing(df)
# Out:
# new_tests                          63.93
# new_tests_per_thousand             63.93
# total_tests                        63.08
# total_tests_per_thousand           63.08
# tests_per_case                     62.33
# positive_rate                      61.44
# new_tests_smoothed                 59.12
# new_tests_smoothed_per_thousand    59.12
# handwashing_facilities             57.90
# tests_units                        57.42
# extreme_poverty                    41.60
# male_smokers                       31.44
# female_smokers                     30.54
# hospital_beds_per_thousand         19.74
# stringency_index                   17.03
# human_development_index            14.11
# aged_65_older                      12.30
# gdp_per_capita                     12.14
# aged_70_older                      11.43
# cardiovasc_death_rate              10.99
# median_age                         10.96
# diabetes_prevalence                 7.77
# population_density                  5.19
# new_cases_smoothed_per_million      3.41
# new_deaths_smoothed_per_million     3.41
# new_cases_smoothed                  3.28
# new_deaths_smoothed                 3.28
# new_cases_per_million               1.85
# total_cases_per_million             1.85
# new_deaths_per_million              1.85
# total_deaths_per_million            1.85
# life_expectancy                     1.85
# new_deaths                          1.72
# new_cases                           1.72
# total_deaths                        1.27
# total_cases                         1.27
# continent                           1.16
# population                          0.58
# iso_code                            0.58
# location                            0.00
# date                                0.00
# dtype: float64

# %%
limitPer = len(df) * .80
df = df.dropna(thresh=limitPer, axis=1)

# %%
# We can also determine the null values in-terms of percentage

# %%
features_with_na=[features for features in new_zealand.columns if new_zealand[features].isnull().sum()>1]
for feature in features_with_na:
    print(feature, np.round(new_zealand[feature].isnull().mean(), 4),  ' % missing values')
# Out:
# total_cases 0.031  % missing values
# new_cases 0.031  % missing values
# new_cases_smoothed 0.0207  % missing values
# total_deaths 0.031  % missing values
# new_deaths 0.031  % missing values
# new_deaths_smoothed 0.0207  % missing values
# total_cases_per_million 0.031  % missing values
# new_cases_per_million 0.031  % missing values
# new_cases_smoothed_per_million 0.0207  % missing values
# total_deaths_per_million 0.031  % missing values
# new_deaths_per_million 0.031  % missing values
# new_deaths_smoothed_per_million 0.0207  % missing values
# new_tests 0.2448  % missing values
# total_tests 0.2448  % missing values
# total_tests_per_thousand 0.2448  % missing values
# new_tests_per_thousand 0.2448  % missing values
# new_tests_smoothed 0.269  % missing values
# new_tests_smoothed_per_thousand 0.269  % missing values
# tests_per_case 0.331  % missing values
# positive_rate 0.269  % missing values
# tests_units 0.2448  % missing values
# stringency_index 0.031  % missing values
# extreme_poverty 1.0  % missing values
# handwashing_facilities 1.0  % missing values

# %%
new_zealand.isnull().sum()
# Out:
# iso_code                             0
# continent                            0
# location                             0
# date                                 0
# total_cases                          9
# new_cases                            9
# new_cases_smoothed                   6
# total_deaths                         9
# new_deaths                           9
# new_deaths_smoothed                  6
# total_cases_per_million              9
# new_cases_per_million                9
# new_cases_smoothed_per_million       6
# total_deaths_per_million             9
# new_deaths_per_million               9
# new_deaths_smoothed_per_million      6
# new_tests                           71
# total_tests                         71
# total_tests_per_thousand            71
# new_tests_per_thousand              71
# new_tests_smoothed                  78
# new_tests_smoothed_per_thousand     78
# tests_per_case                      96
# positive_rate                       78
# tests_units                         71
# stringency_index                     9
# population                           0
# population_density                   0
# median_age                           0
# aged_65_older                        0
# aged_70_older                        0
# gdp_per_capita                       0
# extreme_poverty                    290
# cardiovasc_death_rate                0
# diabetes_prevalence                  0
# female_smokers                       0
# male_smokers                         0
# handwashing_facilities             290
# hospital_beds_per_thousand           0
# life_expectancy                      0
# human_development_index              0
# dtype: int64

# %%
#We now find the null values present in the given series of object. Using the 'isnull().sum()' function, one can find the number of missing values per coumn.

# %%
print(new_zealand.shape)
# Out:
# (290, 41)

# %%
The Slovakia.shape tells that there are 290 rows and 41 columns in the DataFrame for the country Slovakia

# %%
#Using the heatmap, we can clearly locate the null values present in each column if any

# %%
plt.figure(figsize=(25,5))
sns.heatmap(new_zealand.isnull(),yticklabels=False)
plt.title("Heatmap showing the null values present in dataframe-new_zealand_EDA")
# Out:
# Text(0.5, 1.0, 'Heatmap showing the null values present in dataframe-new_zealand_EDA')

# %%
#Columns having more than 80 percent missing values

# %%
def rmissingvaluecol(dff, threshold):
    l = []
    l = list(dff.drop(dff.loc[:,list((100*(dff.isnull().sum()/len(dff.index)) >= threshold))].columns, 1).columns.values)
    print("# Columns having more than %s percent missing values: "%threshold, (dff.shape[1] - len(l)))
    print("Columns:\n", list(set(list((dff.columns.values))) - set(l)))
    return l


rmissingvaluecol(df,80) # Here threshold is 80% which means we are going to drop columns having more than 80% of missing values
# Columns having more than 80 percent missing values:  0
# Out:
# # Columns having more than 80 percent missing values:  0
# Columns:
#  []
# ['iso_code',
#  'continent',
#  'location',
#  'date',
#  'total_cases',
#  'new_cases',
#  'new_cases_smoothed',
#  'total_deaths',
#  'new_deaths',
#  'new_deaths_smoothed',
#  'total_cases_per_million',
#  'new_cases_per_million',
#  'new_cases_smoothed_per_million',
#  'total_deaths_per_million',
#  'new_deaths_per_million',
#  'new_deaths_smoothed_per_million',
#  'stringency_index',
#  'population',
#  'population_density',
#  'median_age',
#  'aged_65_older',
#  'aged_70_older',
#  'gdp_per_capita',
#  'cardiovasc_death_rate',
#  'diabetes_prevalence',
#  'hospital_beds_per_thousand',
#  'life_expectancy',
#  'human_development_index']

# %%
l = rmissingvaluecol(df, 80)
df1 = df[l]
# Columns having more than 80 percent missing values:  0
# Out:
# # Columns having more than 80 percent missing values:  0
# Columns:
#  []

# %%
new_zealand.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 290 entries, 34882 to 35171
# Data columns (total 41 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   iso_code                         290 non-null    object
#  1   continent                        290 non-null    object
#  2   location                         290 non-null    object
#  3   date                             290 non-null    object
#  4   total_cases                      281 non-null    float64
#  5   new_cases                        281 non-null    float64
#  6   new_cases_smoothed               284 non-null    float64
#  7   total_deaths                     281 non-null    float64
#  8   new_deaths                       281 non-null    float64
#  9   new_deaths_smoothed              284 non-null    float64
#  10  total_cases_per_million          281 non-null    float64
#  11  new_cases_per_million            281 non-null    float64
#  12  new_cases_smoothed_per_million   284 non-null    float64
#  13  total_deaths_per_million         281 non-null    float64
#  14  new_deaths_per_million           281 non-null    float64
#  15  new_deaths_smoothed_per_million  284 non-null    float64
#  16  new_tests                        219 non-null    float64
#  17  total_tests                      219 non-null    float64
#  18  total_tests_per_thousand         219 non-null    float64
#  19  new_tests_per_thousand           219 non-null    float64
#  20  new_tests_smoothed               212 non-null    float64
#  21  new_tests_smoothed_per_thousand  212 non-null    float64
#  22  tests_per_case                   194 non-null    float64
#  23  positive_rate                    212 non-null    float64
#  24  tests_units                      219 non-null    object
#  25  stringency_index                 281 non-null    float64
#  26  population                       290 non-null    float64
#  27  population_density               290 non-null    float64
#  28  median_age                       290 non-null    float64
#  29  aged_65_older                    290 non-null    float64
#  30  aged_70_older                    290 non-null    float64
#  31  gdp_per_capita                   290 non-null    float64
#  32  extreme_poverty                  0 non-null      float64
#  33  cardiovasc_death_rate            290 non-null    float64
#  34  diabetes_prevalence              290 non-null    float64
#  35  female_smokers                   290 non-null    float64
#  36  male_smokers                     290 non-null    float64
#  37  handwashing_facilities           0 non-null      float64
#  38  hospital_beds_per_thousand       290 non-null    float64
#  39  life_expectancy                  290 non-null    float64
#  40  human_development_index          290 non-null    float64
# dtypes: float64(36), object(5)
# memory usage: 95.2+ KB

# %%
#Correlation Matrix of Slovakia_EDA

# %%
new_zealand_corr = new_zealand[['new_cases_smoothed','total_deaths','new_deaths','new_deaths_smoothed','new_cases_smoothed_per_million',
                           'new_deaths_per_million','total_deaths_per_million','new_deaths_smoothed_per_million']].corr()
plt.figure(figsize=(15,10))
sns.heatmap(new_zealand_corr,annot = True,vmin =1,vmax=1,cmap ='GnBu_r')
plt.title("Correlation Matrix of new_zealand_EDA")
new_zealand_corr
# Out:
#                                  new_cases_smoothed  total_deaths  new_deaths  \
# new_cases_smoothed                         1.000000     -0.300400    0.133848
# total_deaths                              -0.300400      1.000000   -0.021715
# new_deaths                                 0.133848     -0.021715    1.000000
# new_deaths_smoothed                        0.123825      0.011174    0.591345
# new_cases_smoothed_per_million             1.000000     -0.300409    0.133854
# new_deaths_per_million                     0.133817     -0.021720    1.000000
# total_deaths_per_million                  -0.300430      1.000000   -0.021719
# new_deaths_smoothed_per_million            0.124603      0.011122    0.591291
#
#                                  new_deaths_smoothed  \
# new_cases_smoothed                          0.123825
# total_deaths                                0.011174
# new_deaths                                  0.591345
# new_deaths_smoothed                         1.000000
# new_cases_smoothed_per_million              0.123827
# new_deaths_per_million                      0.591262
# total_deaths_per_million                    0.011170
# new_deaths_smoothed_per_million             0.999996
#
#                                  new_cases_smoothed_per_million  \
# new_cases_smoothed                                     1.000000
# total_deaths                                          -0.300409
# new_deaths                                             0.133854
# new_deaths_smoothed                                    0.123827
# new_cases_smoothed_per_million                         1.000000
# new_deaths_per_million                                 0.133824
# total_deaths_per_million                              -0.300439
# new_deaths_smoothed_per_million                        0.124605
#
#                                  new_deaths_per_million  \
# new_cases_smoothed                             0.133817
# total_deaths                                  -0.021720
# new_deaths                                     1.000000
# new_deaths_smoothed                            0.591262
# new_cases_smoothed_per_million                 0.133824
# new_deaths_per_million                         1.000000
# total_deaths_per_million                      -0.021724
# new_deaths_smoothed_per_million                0.591208
#
#                                  total_deaths_per_million  \
# new_cases_smoothed                              -0.300430
# total_deaths                                     1.000000
# new_deaths                                      -0.021719
# new_deaths_smoothed                              0.011170
# new_cases_smoothed_per_million                  -0.300439
# new_deaths_per_million                          -0.021724
# total_deaths_per_million                         1.000000
# new_deaths_smoothed_per_million                  0.011118
#
#                                  new_deaths_smoothed_per_million
# new_cases_smoothed                                      0.124603
# total_deaths                                            0.011122
# new_deaths                                              0.591291
# new_deaths_smoothed                                     0.999996
# new_cases_smoothed_per_million                          0.124605
# new_deaths_per_million                                  0.591208
# total_deaths_per_million                                0.011118
# new_deaths_smoothed_per_million                         1.000000

# %%
new_zealand.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 290 entries, 34882 to 35171
# Data columns (total 41 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   iso_code                         290 non-null    object
#  1   continent                        290 non-null    object
#  2   location                         290 non-null    object
#  3   date                             290 non-null    object
#  4   total_cases                      281 non-null    float64
#  5   new_cases                        281 non-null    float64
#  6   new_cases_smoothed               284 non-null    float64
#  7   total_deaths                     281 non-null    float64
#  8   new_deaths                       281 non-null    float64
#  9   new_deaths_smoothed              284 non-null    float64
#  10  total_cases_per_million          281 non-null    float64
#  11  new_cases_per_million            281 non-null    float64
#  12  new_cases_smoothed_per_million   284 non-null    float64
#  13  total_deaths_per_million         281 non-null    float64
#  14  new_deaths_per_million           281 non-null    float64
#  15  new_deaths_smoothed_per_million  284 non-null    float64
#  16  new_tests                        219 non-null    float64
#  17  total_tests                      219 non-null    float64
#  18  total_tests_per_thousand         219 non-null    float64
#  19  new_tests_per_thousand           219 non-null    float64
#  20  new_tests_smoothed               212 non-null    float64
#  21  new_tests_smoothed_per_thousand  212 non-null    float64
#  22  tests_per_case                   194 non-null    float64
#  23  positive_rate                    212 non-null    float64
#  24  tests_units                      219 non-null    object
#  25  stringency_index                 281 non-null    float64
#  26  population                       290 non-null    float64
#  27  population_density               290 non-null    float64
#  28  median_age                       290 non-null    float64
#  29  aged_65_older                    290 non-null    float64
#  30  aged_70_older                    290 non-null    float64
#  31  gdp_per_capita                   290 non-null    float64
#  32  extreme_poverty                  0 non-null      float64
#  33  cardiovasc_death_rate            290 non-null    float64
#  34  diabetes_prevalence              290 non-null    float64
#  35  female_smokers                   290 non-null    float64
#  36  male_smokers                     290 non-null    float64
#  37  handwashing_facilities           0 non-null      float64
#  38  hospital_beds_per_thousand       290 non-null    float64
#  39  life_expectancy                  290 non-null    float64
#  40  human_development_index          290 non-null    float64
# dtypes: float64(36), object(5)
# memory usage: 95.2+ KB

# %% [markdown]
#  After removing the missing values, the shape of the dataset has been changed to (374, 29) from (374, 59)
